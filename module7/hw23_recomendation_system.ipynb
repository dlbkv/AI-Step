# %% [markdown]
# <a href="https://colab.research.google.com/github/dlbkv/AI-Step/blob/master/module7/hw23_recomendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання
#
# * Створіть Reader
# * Створіть датасет та розділіть його на тренувальні та тестові дані
# * Виберіть метрики для поріняння якості моделей
# * На основі метрик виберіть найкращу модель

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module7/data/ratings.csv")

df.head()
# Out:
#    user_id  movie_id  rating   timestamp
# 0      172     94969     5.0  1396067836
# 1      172     98956     4.0  1396067879
# 2      176     73881     4.0  1499807147
# 3      221      1900     4.5  1288550866
# 4      333     33688     4.0  1412015122

# %%
df.describe()
# Out:
#              user_id       movie_id        rating     timestamp
# count   17604.000000   17604.000000  17604.000000  1.760400e+04
# mean   141251.609009   88913.605942      3.465945  1.403256e+09
# std     81731.882435   51285.238375      1.203144  1.515083e+08
# min       172.000000     139.000000      0.500000  8.282224e+08
# 25%     71256.000000   55098.000000      3.000000  1.395695e+09
# 50%    138487.000000   89554.000000      3.500000  1.456552e+09
# 75%    210264.500000  134779.500000      4.500000  1.494418e+09
# max    283195.000000  193843.000000      5.000000  1.537934e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17604 entries, 0 to 17603
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    17604 non-null  int64
#  1   movie_id   17604 non-null  int64
#  2   rating     17604 non-null  float64
#  3   timestamp  17604 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 550.2 KB

# %%
try:
  from surprise import Dataset, Reader
except ModuleNotFoundError:
  # !pip install -q surprise
  from surprise import Dataset, Reader

reader = Reader(rating_scale=(0, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df[["user_id", "movie_id", "rating"]], reader)

# %%
from surprise.model_selection import train_test_split
from surprise import BaselineOnly, SVD, KNNBasic, CoClustering, accuracy

trainset, testset = train_test_split(data, train_size=0.8)

# %%
try:
  import optuna
except ModuleNotFoundError:
  # !pip install -q optuna
  import optuna
import time

def objective(trial):

    start_time = time.time()
    print(f"Iteration: {trial.number}")


    algo_type = trial.suggest_categorical('algo_type', ['BaselineOnly','SVD','KNNBasic', 'CoClustering'])

    if algo_type == 'BaselineOnly':
        method_type = trial.suggest_categorical('method_type', ['sgd', 'als'])
        if method_type == 'sgd':
          params = {
              'method': 'sgd',
              'learning_rate': trial.suggest_float('learning_rate', 1e-6, 1.0, log=True),
              'n_epochs': 20,
          }
        else:
          params = {
              'method': 'als',
              'reg_u': trial.suggest_float('reg_u', 1e-6, 1.0, log=True),
              'reg_i': trial.suggest_float('reg_i', 1e-6, 1.0, log=True),
              'n_epochs': 20,
          }

        algo = BaselineOnly(bsl_options=params)

    elif algo_type == 'SVD':
        params = {
            'n_factors': trial.suggest_int('n_factors', 10, 150),
            'reg_all': trial.suggest_float('reg_all', 1e-6, 1.0, log=True),
            'lr_all': trial.suggest_float('lr_all', 1e-6, 1.0, log=True),

        }

        algo = SVD(**params)

    elif algo_type == 'KNNBasic':

        params = {
            'k': 10,
            'min_k': 1,
        }

        sim_params = {
            'min_support': 1,
            'name': trial.suggest_categorical('name', ['cosine', 'pearson', 'msd']),
            'user_based': trial.suggest_categorical('user_based', [True, False]),
        }

        algo = KNNBasic(**params, sim_options=sim_params)

    elif algo_type == 'CoClustering':
      params = {
            'n_epochs': 20,
            'n_cltr_u': trial.suggest_int('n_cltr_u', 1, 20),
            'n_cltr_i': trial.suggest_int('n_cltr_i', 1, 20),

        }

      algo = CoClustering(**params)

    algo.fit(trainset)

    preds = algo.test(testset)
    metric = accuracy.mse(preds, verbose=False)

    end_time = time.time()
    iteration_time = end_time - start_time

    print(f"mae = {accuracy.mae(preds, verbose=False)}")
    print(f"mse = {accuracy.mse(preds, verbose=False)}")
    print(f"rmse= {accuracy.rmse(preds, verbose=False)}")
    print(f"fcp = {accuracy.fcp(preds, verbose=False)}")
    print()
    print(f"Iteration time: {iteration_time} seconds")

    return metric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.2 MB/s eta 0:00:00

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=500)
# Out:
# Iteration: 0
# Estimating biases using sgd...
# mae = 0.848430971801441
# mse = 1.2308413794424293
# rmse= 1.1094329089415138
# fcp = 0.610849933628867
#
# Iteration time: 0.1317906379699707 seconds
# Iteration: 1
# Estimating biases using sgd...
# mae = 0.9205296980397063
# mse = 1.400130084250141
# rmse= 1.1832709259717915
# fcp = 0.6105230170408376
#
# Iteration time: 0.09775972366333008 seconds
# Iteration: 2
# Estimating biases using als...
# mae = 0.6622843590285994
# mse = 0.8354184229060416
# rmse= 0.9140122662776696
# fcp = 0.6620363843118946
#
# Iteration time: 0.2301619052886963 seconds
# Iteration: 3
# Estimating biases using sgd...
# mae = 0.6908601369145082
# mse = 0.8513104173159761
# rmse= 0.9226648456053672
# fcp = 0.6541071627379736
#
# Iteration time: 0.10670137405395508 seconds
# Iteration: 4
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# mae = 0.7726448267576927
# mse = 1.0614245004213367
# rmse= 1.0302545803932817
# fcp = 0.49477520579373563
#
# Iteration time: 0.3265988826751709 seconds
# Iteration: 5
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# mae = 0.7255311469644258
# mse = 0.9486301898627227
# rmse= 0.9739764832185235
# fcp = 0.6417518958900967
#
# Iteration time: 0.25573182106018066 seconds
# Iteration: 6
# Estimating biases using als...
# mae = 0.6675900786536135
# mse = 0.8305415474385169
# rmse= 0.9113405222190644
# fcp = 0.652921061866823
#
# Iteration time: 0.08018946647644043 seconds
# Iteration: 7
# Estimating biases using als...
# mae = 0.6642992671635084
# mse = 0.8349071313669643
# rmse= 0.9137325272567264
# fcp = 0.6581816500291903
#
# Iteration time: 0.074249267578125 seconds
# Iteration: 8
# mae = 0.9311191704934201
# mse = 1.4154267164340104
# rmse= 1.189717074112165
# fcp = 0.49067934442637307
#
# Iteration time: 0.32053232192993164 seconds
# Iteration: 9
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# mae = 0.8031553756231441
# mse = 1.1096309288890729
# rmse= 1.0533902073254113
# fcp = 0.6766933260385998
#
# Iteration time: 1.7758619785308838 seconds
# Iteration: 10
# mae = 0.7902724737393424
# mse = 1.075399023950547
# rmse= 1.0370144762492697
# fcp = 0.677621794331887
#
# Iteration time: 2.160724401473999 seconds
# Iteration: 11
# Estimating biases using als...
# mae = 0.6682124895221847
# mse = 0.8232593951643749
# rmse= 0.9073364288754061
# fcp = 0.6489344285975674
#
# Iteration time: 0.23153066635131836 seconds
# Iteration: 12
# mae = 0.7926866199952223
# mse = 1.0738157468588658
# rmse= 1.0362508127180725
# fcp = 0.660437344396497
#
# Iteration time: 1.770216703414917 seconds
# Iteration: 13
# mae = 1.4914047896059126
# mse = 3.6452243884036992
# rmse= 1.909247073692585
# fcp = 0.0
#
# Iteration time: 0.2773404121398926 seconds
# Iteration: 14
# Estimating biases using als...
# mae = 0.6743000170006822
# mse = 0.827027251069628
# rmse= 0.9094103864975526
# fcp = 0.6528434486488269
#
# Iteration time: 0.1994774341583252 seconds
# Iteration: 15
# Estimating biases using als...
# mae = 0.6725894481091549
# mse = 0.8250137902474172
# rmse= 0.908302697478884
# fcp = 0.6515764282952419
#
# Iteration time: 0.19287562370300293 seconds
# Iteration: 16
# Estimating biases using als...
# mae = 0.6687662841339799
# mse = 0.8392682303098309
# rmse= 0.9161158389143979
# fcp = 0.6590214217033085
#
# Iteration time: 0.34299755096435547 seconds
# Iteration: 17
# mae = 0.7925521707272685
# mse = 1.068505465749302
# rmse= 1.0336853804467305
# fcp = 0.6662079319404478
#
# Iteration time: 2.4796199798583984 seconds
# Iteration: 18
# mae = 0.721346909583288
# mse = 0.9225546806812244
# rmse= 0.9604971008187502
# fcp = 0.6309402400468936
#
# Iteration time: 1.0148804187774658 seconds
# Iteration: 19
# Estimating biases using als...
# mae = 0.6680505825540979
# mse = 0.8352591545764939
# rmse= 0.9139251361990729
# fcp = 0.6572340183301519
#
# Iteration time: 0.39160871505737305 seconds
# Iteration: 20
# Estimating biases using als...
# mae = 0.674739057124391
# mse = 0.8275900876501534
# rmse= 0.9097197852361756
# fcp = 0.652775655893668
#
# Iteration time: 0.42326784133911133 seconds
# Iteration: 21
# Estimating biases using als...
# mae = 0.6745893715260803
# mse = 0.8274091641430886
# rmse= 0.9096203406603706
# fcp = 0.652775655893668
#
# Iteration time: 0.28611040115356445 seconds
# Iteration: 22
# Estimating biases using als...
# mae = 0.6678201069615204
# mse = 0.8327935732438327
# rmse= 0.9125752425109026
# fcp = 0.6549460169244237
#
# Iteration time: 0.08458328247070312 seconds
# Iteration: 23
# Estimating biases using als...
# mae = 0.6714227721884342
# mse = 0.823931561609898
# rmse= 0.9077067597026575
# fcp = 0.650573590517328
#
# Iteration time: 0.13846373558044434 seconds
# Iteration: 24
# Estimating biases using als...
# mae = 0.6684474915031838
# mse = 0.8376499788020272
# rmse= 0.9152321993909672
# fcp = 0.6596524672528261
#
# Iteration time: 0.12093567848205566 seconds
# Iteration: 25
# Estimating biases using als...
# mae = 0.6673583460381128
# mse = 0.827770816474597
# rmse= 0.9098191119528085
# fcp = 0.651413538999382
#
# Iteration time: 0.13706445693969727 seconds
# Iteration: 26
# mae = 0.8174901124965973
# mse = 1.1355930868154092
# rmse= 1.0656421007145922
# fcp = 0.6848368874866412
#
# Iteration time: 1.4109876155853271 seconds
# Iteration: 27
# mae = 0.9357884012644678
# mse = 1.42908350406527
# rmse= 1.195442806689333
# fcp = 0.5180586500028364
#
# Iteration time: 0.39823269844055176 seconds
# Iteration: 28
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# mae = 0.9077703571794229
# mse = 1.3581584509433942
# rmse= 1.1654005538626597
# fcp = 0.7183502930615859
#
# Iteration time: 3.1663818359375 seconds
# Iteration: 29
# Estimating biases using als...
# mae = 0.6686551143762425
# mse = 0.8389345865865162
# rmse= 0.9159337239050194
# fcp = 0.6588862497126703
#
# Iteration time: 0.132979154586792 seconds
# Iteration: 30
# Estimating biases using sgd...
# mae = 0.9169498323026886
# mse = 1.4007348751537054
# rmse= 1.1835264573103996
# fcp = 0.5812730735407338
#
# Iteration time: 0.29340219497680664 seconds
# Iteration: 31
# Estimating biases using als...
# mae = 0.6740312518598383
# mse = 0.8266797017753323
# rmse= 0.9092192814581818
# fcp = 0.651372759382206
#
# Iteration time: 0.12134957313537598 seconds
# Iteration: 32
# Estimating biases using als...
# mae = 0.6674262024293498
# mse = 0.8248240721204276
# rmse= 0.9081982559553986
# fcp = 0.6556602303769332
#
# Iteration time: 0.10175895690917969 seconds
# Iteration: 33
# Estimating biases using als...
# mae = 0.6673214680324234
# mse = 0.8268400509347759
# rmse= 0.9093074567684881
# fcp = 0.6542807582560892
#
# Iteration time: 0.09228062629699707 seconds
# Iteration: 34
# Estimating biases using als...
# mae = 0.6684052011396391
# mse = 0.8374003661455899
# rmse= 0.9150958234772957
# fcp = 0.6597199373657439
#
# Iteration time: 0.08440446853637695 seconds
# Iteration: 35
# Estimating biases using als...
# mae = 0.6673302203642546
# mse = 0.8257069761983445
# rmse= 0.9086842004780014
# fcp = 0.6550368476739978
#
# Iteration time: 0.0803689956665039 seconds
# Iteration: 36
# Estimating biases using als...
# mae = 0.6681832408880884
# mse = 0.8375184650577334
# rmse= 0.9151603493692968
# fcp = 0.6585483524402757
#
# Iteration time: 0.08561873435974121 seconds
# Iteration: 37
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# mae = 0.8999521789070305
# mse = 1.3520665822226643
# rmse= 1.1627839791735455
# fcp = 0.6484353536099177
#
# Iteration time: 1.855799913406372 seconds
# Iteration: 38
# Estimating biases using als...
# mae = 0.6674851677930871
# mse = 0.824545583828922
# rmse= 0.9080449239046061
# fcp = 0.6554570208434671
#
# Iteration time: 0.13539648056030273 seconds
# Iteration: 39
# Estimating biases using als...
# mae = 0.6682576593467207
# mse = 0.8366171402911776
# rmse= 0.9146677759116573
# fcp = 0.6584807785916109
#
# Iteration time: 0.15055012702941895 seconds
# Iteration: 40
# Estimating biases using sgd...
# mae = 0.9294692930824466
# mse = 1.4193727874870565
# rmse= 1.1913743271898454
# fcp = 0.6098646237386776
#
# Iteration time: 0.17014265060424805 seconds
# Iteration: 41
# Estimating biases using als...
# mae = 0.667355128573154
# mse = 0.8254333558835841
# rmse= 0.908533629473111
# fcp = 0.6551046794179319
#
# Iteration time: 0.1286616325378418 seconds
# Iteration: 42
# Estimating biases using als...
# mae = 0.6674146127396267
# mse = 0.8248848918306204
# rmse= 0.9082317390570649
# fcp = 0.6555924919114766
#
# Iteration time: 0.11260533332824707 seconds
# Iteration: 43
# Estimating biases using als...
# mae = 0.667384198335231
# mse = 0.8250910473026717
# rmse= 0.9083452247370885
# fcp = 0.6550368476739978
#
# Iteration time: 0.1137855052947998 seconds
# Iteration: 44
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# mae = 0.7704261017262387
# mse = 1.055004050606433
# rmse= 1.0271339010111744
# fcp = 0.5071067415267254
#
# Iteration time: 0.2247772216796875 seconds
# Iteration: 45
# Estimating biases using als...
# mae = 0.6679021645454297
# mse = 0.8337419590513107
# rmse= 0.913094715268526
# fcp = 0.6548781621014182
#
# Iteration time: 0.16797542572021484 seconds
# Iteration: 46
# mae = 0.8037282748333358
# mse = 1.116739784444967
# rmse= 1.0567590948011598
# fcp = 0.5873770807892539
#
# Iteration time: 0.47958993911743164 seconds
# Iteration: 47
# mae = 0.7951403438882578
# mse = 1.0840295189088363
# rmse= 1.04116738275305
# fcp = 0.6648624055408746
#
# Iteration time: 1.6084959506988525 seconds
# Iteration: 48
# Estimating biases using als...
# mae = 0.667632104291448
# mse = 0.8240449339032175
# rmse= 0.907769207399776
# fcp = 0.6551183773697687
#
# Iteration time: 0.18364715576171875 seconds
# Iteration: 49
# Estimating biases using sgd...
# mae = 0.7421666375486622
# mse = 0.9575760328272728
# rmse= 0.9785581397276673
# fcp = 0.6490816990037296
#
# Iteration time: 0.14647960662841797 seconds
# Iteration: 50
# Estimating biases using als...
# mae = 0.6680124506215697
# mse = 0.8234355191063781
# rmse= 0.9074334791632818
# fcp = 0.651424621693588
#
# Iteration time: 0.08523273468017578 seconds
# Iteration: 51
# Estimating biases using als...
# mae = 0.6681306595476024
# mse = 0.8233171913647063
# rmse= 0.907368277693631
# fcp = 0.6489344285975674
#
# Iteration time: 0.08118700981140137 seconds
# Iteration: 52
# Estimating biases using als...
# mae = 0.6677352005533463
# mse = 0.8320168700997967
# rmse= 0.9121495875676295
# fcp = 0.6559989520221183
#
# Iteration time: 0.08745312690734863 seconds
# Iteration: 53
# Estimating biases using als...
# mae = 0.6685832470362336
# mse = 0.8230443697208982
# rmse= 0.9072179284609063
# fcp = 0.6481162322719789
#
# Iteration time: 0.08978915214538574 seconds
# Iteration: 54
# Estimating biases using sgd...
# mae = 0.7461779015985652
# mse = 0.9677016719036639
# rmse= 0.9837182888935551
# fcp = 0.6493813151189093
#
# Iteration time: 0.10927057266235352 seconds
# Iteration: 55
# mae = 0.7996117342331804
# mse = 1.0795726748965175
# rmse= 1.0390248673138278
# fcp = 0.6809791806052974
#
# Iteration time: 0.8917591571807861 seconds
# Iteration: 56
# mae = 0.8078559403495775
# mse = 1.1259016268360231
# rmse= 1.0610851176206475
# fcp = 0.599158961641103
#
# Iteration time: 0.237135648727417 seconds
# Iteration: 57
# Estimating biases using als...
# mae = 0.6687634411511125
# mse = 0.8392573601572881
# rmse= 0.9161099061560726
# fcp = 0.6589538347735061
#
# Iteration time: 0.08890843391418457 seconds
# Iteration: 58
# Estimating biases using als...
# mae = 0.6690486417488543
# mse = 0.8229069098261987
# rmse= 0.9071421662706451
# fcp = 0.6481844032633883
#
# Iteration time: 0.10828781127929688 seconds
# Iteration: 59
# Estimating biases using als...
# mae = 0.6688577749555381
# mse = 0.8229272907314057
# rmse= 0.9071533997794451
# fcp = 0.6481844032633883
#
# Iteration time: 0.08794832229614258 seconds
# Iteration: 60
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# mae = 0.7255311469644258
# mse = 0.9486301898627227
# rmse= 0.9739764832185235
# fcp = 0.6417518958900967
#
# Iteration time: 0.16667890548706055 seconds
# Iteration: 61
# Estimating biases using als...
# mae = 0.6691199016500178
# mse = 0.8229061926422699
# rmse= 0.9071417709720294
# fcp = 0.6480480634684262
#
# Iteration time: 0.08846306800842285 seconds
# Iteration: 62
# Estimating biases using als...
# mae = 0.6676308411489678
# mse = 0.8310722870499994
# rmse= 0.9116316619391844
# fcp = 0.6537787112854019
#
# Iteration time: 0.08294677734375 seconds
# Iteration: 63
# Estimating biases using als...
# mae = 0.6690128721091766
# mse = 0.8227746391555734
# rmse= 0.9070692581912218
# fcp = 0.6481844032633883
#
# Iteration time: 0.08706259727478027 seconds
# Iteration: 64
# Estimating biases using als...
# mae = 0.6674107348579065
# mse = 0.8298706314014097
# rmse= 0.9109723549051364
# fcp = 0.6526489065578686
#
# Iteration time: 0.12195968627929688 seconds
# Iteration: 65
# Estimating biases using als...
# mae = 0.6685516388127175
# mse = 0.8215768708081952
# rmse= 0.9064087768817087
# fcp = 0.6489508282934526
#
# Iteration time: 0.15761566162109375 seconds
# Iteration: 66
# Estimating biases using als...
# mae = 0.6686627641064993
# mse = 0.8217859187078511
# rmse= 0.9065240861156703
# fcp = 0.6481162322719789
#
# Iteration time: 0.13161420822143555 seconds
# Iteration: 67
# Estimating biases using als...
# mae = 0.6691866764118182
# mse = 0.8220697097775047
# rmse= 0.9066805996476955
# fcp = 0.648746575234409
#
# Iteration time: 0.1367638111114502 seconds
# Iteration: 68
# mae = 0.7948451040603588
# mse = 1.0831103430234121
# rmse= 1.0407258731401907
# fcp = 0.6500498878626804
#
# Iteration time: 0.9335999488830566 seconds
# Iteration: 69
# Estimating biases using als...
# mae = 0.668870857324244
# mse = 0.820953413330947
# rmse= 0.9060647953269937
# fcp = 0.6500976435663287
#
# Iteration time: 0.07895159721374512 seconds
# Iteration: 70
# Estimating biases using als...
# mae = 0.6668336067373617
# mse = 0.836073644355387
# rmse= 0.9143706274566058
# fcp = 0.6574370506377654
#
# Iteration time: 0.08528470993041992 seconds
# Iteration: 71
# Estimating biases using als...
# mae = 0.668945482887888
# mse = 0.8210016844313826
# rmse= 0.9060914327105088
# fcp = 0.6500976435663287
#
# Iteration time: 0.08563899993896484 seconds
# Iteration: 72
# Estimating biases using als...
# mae = 0.6690608906208794
# mse = 0.8204352899989905
# rmse= 0.90577883061981
# fcp = 0.6494955976562911
#
# Iteration time: 0.11397171020507812 seconds
# Iteration: 73
# Estimating biases using als...
# mae = 0.6698810979164316
# mse = 0.820433616387181
# rmse= 0.905777906766985
# fcp = 0.6498936977825482
#
# Iteration time: 0.12655353546142578 seconds
# Iteration: 74
# Estimating biases using als...
# mae = 0.6722884566402031
# mse = 0.8226636828504795
# rmse= 0.9070080941482714
# fcp = 0.6513411045557017
#
# Iteration time: 0.17539715766906738 seconds
# Iteration: 75
# mae = 0.8205499426794308
# mse = 1.0937758136964675
# rmse= 1.0458373744021905
# fcp = 0.5801832008240513
#
# Iteration time: 0.1918163299560547 seconds
# Iteration: 76
# Estimating biases using als...
# mae = 0.6712449763214909
# mse = 0.8207917636102523
# rmse= 0.9059755866524507
# fcp = 0.6486784951777957
#
# Iteration time: 0.13231158256530762 seconds
# Iteration: 77
# Estimating biases using sgd...
# mae = 0.8964430646911975
# mse = 1.3474071540349675
# rmse= 1.160778684347265
# fcp = 0.6133391524619188
#
# Iteration time: 0.16785144805908203 seconds
# Iteration: 78
# Estimating biases using als...
# mae = 0.6660791041462463
# mse = 0.8264297438396515
# rmse= 0.9090818136117627
# fcp = 0.6509666649404966
#
# Iteration time: 0.1359102725982666 seconds
# Iteration: 79
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# mae = 0.8999521789070305
# mse = 1.3520665822226643
# rmse= 1.1627839791735455
# fcp = 0.6484353536099177
#
# Iteration time: 1.686075210571289 seconds
# Iteration: 80
# Estimating biases using als...
# mae = 0.6676558246611326
# mse = 0.815341019406827
# rmse= 0.9029623576909654
# fcp = 0.6538783548286752
#
# Iteration time: 0.10309648513793945 seconds
# Iteration: 81
# Estimating biases using als...
# mae = 0.6684145480617385
# mse = 0.8161192549468254
# rmse= 0.9033931895619013
# fcp = 0.6515106493524547
#
# Iteration time: 0.09065532684326172 seconds
# Iteration: 82
# Estimating biases using als...
# mae = 0.6692249054314309
# mse = 0.8171868496196206
# rmse= 0.9039838768582218
# fcp = 0.6483986722336673
#
# Iteration time: 0.0867457389831543 seconds
# Iteration: 83
# Estimating biases using als...
# mae = 0.6666386698898141
# mse = 0.814352830843898
# rmse= 0.9024149992347744
# fcp = 0.6537434159935707
#
# Iteration time: 0.10274219512939453 seconds
# Iteration: 84
# Estimating biases using als...
# mae = 0.6688633431202369
# mse = 0.8166683686131612
# rmse= 0.9036970557732061
# fcp = 0.6513260757109893
#
# Iteration time: 0.10192036628723145 seconds
# Iteration: 85
# Estimating biases using als...
# mae = 0.6685139859767745
# mse = 0.8162422434179499
# rmse= 0.9034612572866365
# fcp = 0.6519842226120162
#
# Iteration time: 0.09338140487670898 seconds
# Iteration: 86
# Estimating biases using als...
# mae = 0.6676060190698573
# mse = 0.8152812710047951
# rmse= 0.902929272426581
# fcp = 0.6541482549701461
#
# Iteration time: 0.17196297645568848 seconds
# Iteration: 87
# Estimating biases using als...
# mae = 0.6666818578984419
# mse = 0.8143948321334761
# rmse= 0.9024382705390304
# fcp = 0.6538108844748853
#
# Iteration time: 0.10040497779846191 seconds
# Iteration: 88
# Estimating biases using als...
# mae = 0.6671255039627162
# mse = 0.8148214120476002
# rmse= 0.9026745881255327
# fcp = 0.6537434159935707
#
# Iteration time: 0.11271500587463379 seconds
# Iteration: 89
# Estimating biases using als...
# mae = 0.6616364087830954
# mse = 0.8361642386216213
# rmse= 0.9144201652531626
# fcp = 0.6634903438406854
#
# Iteration time: 0.08846497535705566 seconds
# Iteration: 90
# mae = 0.8973068859918176
# mse = 1.3454922606605213
# rmse= 1.1599535596999224
# fcp = 0.5147316615683971
#
# Iteration time: 0.29200172424316406 seconds
# Iteration: 91
# Estimating biases using als...
# mae = 0.6695108112125119
# mse = 0.8179944922207311
# rmse= 0.9044304794845931
# fcp = 0.6472510215649713
#
# Iteration time: 0.10998320579528809 seconds
# Iteration: 92
# Estimating biases using als...
# mae = 0.670465299784593
# mse = 0.8190863014891708
# rmse= 0.9050338675923519
# fcp = 0.6469101871902472
#
# Iteration time: 0.08812665939331055 seconds
# Iteration: 93
# Estimating biases using als...
# mae = 0.6662932156145268
# mse = 0.8140433922872076
# rmse= 0.9022435326934782
# fcp = 0.6538108844748853
#
# Iteration time: 0.08614349365234375 seconds
# Iteration: 94
# Estimating biases using als...
# mae = 0.6590661637627728
# mse = 0.8197217882287824
# rmse= 0.9053848840293184
# fcp = 0.6630040746529247
#
# Iteration time: 0.10127663612365723 seconds
# Iteration: 95
# mae = 0.8016008821401203
# mse = 1.1071151002173922
# rmse= 1.0521953716954815
# fcp = 0.6651621776665723
#
# Iteration time: 1.617706537246704 seconds
# Iteration: 96
# Estimating biases using als...
# mae = 0.6692473671245126
# mse = 0.8174658626841512
# rmse= 0.9041381878253739
# fcp = 0.6465694077489866
#
# Iteration time: 0.1464536190032959 seconds
# Iteration: 97
# Estimating biases using als...
# mae = 0.6688759116894675
# mse = 0.8166982758091983
# rmse= 0.9037136027576427
# fcp = 0.6511227552088221
#
# Iteration time: 0.1461033821105957 seconds
# Iteration: 98
# Estimating biases using sgd...
# mae = 0.6863141788282391
# mse = 0.8356049754290809
# rmse= 0.914114312014138
# fcp = 0.6642472960386652
#
# Iteration time: 0.1809852123260498 seconds
# Iteration: 99
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# mae = 0.7704261017262387
# mse = 1.055004050606433
# rmse= 1.0271339010111744
# fcp = 0.5071067415267254
#
# Iteration time: 0.3591151237487793 seconds
# Iteration: 100
# Estimating biases using als...
# mae = 0.662728323602125
# mse = 0.8186896758995845
# rmse= 0.9048147190997639
# fcp = 0.6506260850744949
#
# Iteration time: 0.13634371757507324 seconds
# Iteration: 101
# Estimating biases using als...
# mae = 0.6688499788738103
# mse = 0.8166874023238939
# rmse= 0.903707586735828
# fcp = 0.6519613549062973
#
# Iteration time: 0.1670069694519043 seconds
# Iteration: 102
# Estimating biases using als...
# mae = 0.6651268263210961
# mse = 0.8135174899313226
# rmse= 0.901952044141662
# fcp = 0.6526609224237522
#
# Iteration time: 0.09603428840637207 seconds
# Iteration: 103
# Estimating biases using als...
# mae = 0.6636138258985744
# mse = 0.8124000784142897
# rmse= 0.9013323906385977
# fcp = 0.6552394296954649
#
# Iteration time: 0.09122109413146973 seconds
# Iteration: 104
# Estimating biases using als...
# mae = 0.6597072314222433
# mse = 0.8139921958511133
# rmse= 0.902215160508353
# fcp = 0.6600147271550243
#
# Iteration time: 0.14751911163330078 seconds
# Iteration: 105
# Estimating biases using als...
# mae = 0.659050319760387
# mse = 0.8182808832856215
# rmse= 0.9045887923723251
# fcp = 0.6611761912758479
#
# Iteration time: 0.14172625541687012 seconds
# Iteration: 106
# Estimating biases using als...
# mae = 0.6634058404798775
# mse = 0.8168417150643794
# rmse= 0.9037929602870225
# fcp = 0.6496384014414088
#
# Iteration time: 0.1248469352722168 seconds
# Iteration: 107
# Estimating biases using als...
# mae = 0.6644260275154013
# mse = 0.8187652070881435
# rmse= 0.904856456620686
# fcp = 0.6491152244368964
#
# Iteration time: 0.12891030311584473 seconds
# Iteration: 108
# Estimating biases using als...
# mae = 0.6661415961689726
# mse = 0.8146020937508196
# rmse= 0.9025530974689631
# fcp = 0.6512731915558793
#
# Iteration time: 0.13806676864624023 seconds
# Iteration: 109
# Estimating biases using als...
# mae = 0.6662873727750698
# mse = 0.8151695546569651
# rmse= 0.9028674070188629
# fcp = 0.6507299617012864
#
# Iteration time: 0.13691306114196777 seconds
# Iteration: 110
# Estimating biases using als...
# mae = 0.661185501792523
# mse = 0.8276445826882172
# rmse= 0.9097497362946676
# fcp = 0.6580458105823429
#
# Iteration time: 0.0968477725982666 seconds
# Iteration: 111
# Estimating biases using als...
# mae = 0.6657274744756037
# mse = 0.814452772468603
# rmse= 0.9024703720724593
# fcp = 0.6512052806158308
#
# Iteration time: 0.09174919128417969 seconds
# Iteration: 112
# Estimating biases using als...
# mae = 0.6657722463821453
# mse = 0.814727935968087
# rmse= 0.9026228093550965
# fcp = 0.6507299617012864
#
# Iteration time: 0.08888602256774902 seconds
# Iteration: 113
# Estimating biases using als...
# mae = 0.6654127113361865
# mse = 0.8146084839346374
# rmse= 0.9025566375217886
# fcp = 0.6514090196153915
#
# Iteration time: 0.10791611671447754 seconds
# Iteration: 114
# Estimating biases using als...
# mae = 0.665191439541544
# mse = 0.8188213596408631
# rmse= 0.9048874845199613
# fcp = 0.6491152244368964
#
# Iteration time: 0.08403325080871582 seconds
# Iteration: 115
# Estimating biases using als...
# mae = 0.6666969363004421
# mse = 0.8163017444833468
# rmse= 0.9034941861923333
# fcp = 0.6512394514767933
#
# Iteration time: 0.1946403980255127 seconds
# Iteration: 116
# mae = 0.7751926789526639
# mse = 1.0317703780614562
# rmse= 1.0157609847111948
# fcp = 0.6723488392071018
#
# Iteration time: 0.7218461036682129 seconds
# Iteration: 117
# Estimating biases using als...
# mae = 0.6605885639347029
# mse = 0.8169486138863544
# rmse= 0.9038520973513058
# fcp = 0.6508155557643963
#
# Iteration time: 0.07807207107543945 seconds
# Iteration: 118
# Estimating biases using sgd...
# mae = 0.9303746467012575
# mse = 1.4211966024287273
# rmse= 1.192139506277989
# fcp = 0.609798793379635
#
# Iteration time: 0.11541414260864258 seconds
# Iteration: 119
# mae = 0.7331828697618835
# mse = 0.9555646039203968
# rmse= 0.9775298480969248
# fcp = 0.6090143294718835
#
# Iteration time: 0.1853945255279541 seconds
# Iteration: 120
# Estimating biases using als...
# mae = 0.6663450748755855
# mse = 0.8154728003440591
# rmse= 0.9030353261883275
# fcp = 0.6493121254778612
#
# Iteration time: 0.0915679931640625 seconds
# Iteration: 121
# Estimating biases using als...
# mae = 0.6653092076246812
# mse = 0.8141027891699171
# rmse= 0.9022764483072342
# fcp = 0.6520717389364494
#
# Iteration time: 0.08425426483154297 seconds
# Iteration: 122
# Estimating biases using als...
# mae = 0.6619189479118563
# mse = 0.8147039716725967
# rmse= 0.9026095344458736
# fcp = 0.6510413772155234
#
# Iteration time: 0.1032261848449707 seconds
# Iteration: 123
# Estimating biases using als...
# mae = 0.6641391843759961
# mse = 0.8179651222198929
# rmse= 0.9044142426011949
# fcp = 0.6489788852666237
#
# Iteration time: 0.10968470573425293 seconds
# Iteration: 124
# Estimating biases using als...
# mae = 0.6599676451041022
# mse = 0.8189258232888722
# rmse= 0.904945204578085
# fcp = 0.653122866274637
#
# Iteration time: 0.11028814315795898 seconds
# Iteration: 125
# Estimating biases using als...
# mae = 0.662039984378477
# mse = 0.834413039979472
# rmse= 0.9134621174298757
# fcp = 0.6621722353006438
#
# Iteration time: 0.1140279769897461 seconds
# Iteration: 126
# Estimating biases using als...
# mae = 0.6635139774578128
# mse = 0.8159216039094911
# rmse= 0.9032837892431653
# fcp = 0.6487513457600642
#
# Iteration time: 0.10413002967834473 seconds
# Iteration: 127
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# mae = 0.8999521789070305
# mse = 1.3520665822226643
# rmse= 1.1627839791735455
# fcp = 0.6484353536099177
#
# Iteration time: 1.6666209697723389 seconds
# Iteration: 128
# Estimating biases using als...
# mae = 0.6678701735210308
# mse = 0.8178222744047274
# rmse= 0.9043352665934948
# fcp = 0.6516807004547005
#
# Iteration time: 0.12993097305297852 seconds
# Iteration: 129
# Estimating biases using als...
# mae = 0.6647181669724711
# mse = 0.8137333083315026
# rmse= 0.902071675828203
# fcp = 0.6522073401956854
#
# Iteration time: 0.15496206283569336 seconds
# Iteration: 130
# Estimating biases using als...
# mae = 0.662194834771907
# mse = 0.8140542638459415
# rmse= 0.9022495574096678
# fcp = 0.6513817691632693
#
# Iteration time: 0.2704629898071289 seconds
# Iteration: 131
# Estimating biases using als...
# mae = 0.6621316039394973
# mse = 0.8139033395618498
# rmse= 0.9021659157615354
# fcp = 0.6517222141673845
#
# Iteration time: 0.10683727264404297 seconds
# Iteration: 132
# Estimating biases using als...
# mae = 0.6599834302115208
# mse = 0.8224748213437457
# rmse= 0.9069039758120734
# fcp = 0.6573255256381278
#
# Iteration time: 0.10007524490356445 seconds
# Iteration: 133
# Estimating biases using als...
# mae = 0.6639480343834896
# mse = 0.8162214761418973
# rmse= 0.9034497640388741
# fcp = 0.6487513457600642
#
# Iteration time: 0.10477900505065918 seconds
# Iteration: 134
# Estimating biases using als...
# mae = 0.6598333408957991
# mse = 0.8181636543781905
# rmse= 0.9045239932573322
# fcp = 0.6550114679099917
#
# Iteration time: 0.09415078163146973 seconds
# Iteration: 135
# Estimating biases using als...
# mae = 0.6667922154617922
# mse = 0.8197102663226605
# rmse= 0.90537852101906
# fcp = 0.6481374481232011
#
# Iteration time: 0.09556913375854492 seconds
# Iteration: 136
# Estimating biases using als...
# mae = 0.6644520490453378
# mse = 0.8197867909339044
# rmse= 0.9054207811475857
# fcp = 0.6477537655533726
#
# Iteration time: 0.10081911087036133 seconds
# Iteration: 137
# Estimating biases using als...
# mae = 0.6653890631852577
# mse = 0.8141575104414718
# rmse= 0.902306771802956
# fcp = 0.6520039413219706
#
# Iteration time: 0.09087109565734863 seconds
# Iteration: 138
# Estimating biases using als...
# mae = 0.6647340081557672
# mse = 0.8131918030156088
# rmse= 0.9017714804847228
# fcp = 0.6529993458458897
#
# Iteration time: 0.10489845275878906 seconds
# Iteration: 139
# Estimating biases using als...
# mae = 0.6617744698623195
# mse = 0.8357125427941845
# rmse= 0.914173147053765
# fcp = 0.6647390634584286
#
# Iteration time: 0.10326147079467773 seconds
# Iteration: 140
# mae = 0.8125463017104146
# mse = 1.1448454962693224
# rmse= 1.0699745306638482
# fcp = 0.6653432369653219
#
# Iteration time: 1.1106951236724854 seconds
# Iteration: 141
# Estimating biases using als...
# mae = 0.6676201711136989
# mse = 0.8172238754109328
# rmse= 0.9040043558583846
# fcp = 0.6518509922246721
#
# Iteration time: 0.11902809143066406 seconds
# Iteration: 142
# Estimating biases using als...
# mae = 0.6649926892992153
# mse = 0.8132466534507604
# rmse= 0.9018018925743949
# fcp = 0.6520978383698466
#
# Iteration time: 0.11359643936157227 seconds
# Iteration: 143
# Estimating biases using als...
# mae = 0.6625711190709169
# mse = 0.813071584585541
# rmse= 0.9017048212056654
# fcp = 0.6562958235910527
#
# Iteration time: 0.11049246788024902 seconds
# Iteration: 144
# Estimating biases using als...
# mae = 0.6622609750879846
# mse = 0.8130368947634019
# rmse= 0.9016855853141947
# fcp = 0.6548500137795287
#
# Iteration time: 0.10908222198486328 seconds
# Iteration: 145
# Estimating biases using als...
# mae = 0.661483357089184
# mse = 0.8131499533662216
# rmse= 0.9017482760539227
# fcp = 0.6546466276449098
#
# Iteration time: 0.10362482070922852 seconds
# Iteration: 146
# Estimating biases using sgd...
# mae = 1.8394917340442187
# mse = 5.284271693612935
# rmse= 2.2987543787044613
# fcp = 0.3485234921204022
#
# Iteration time: 0.12434673309326172 seconds
# Iteration: 147
# mae = 0.8955216474625185
# mse = 1.3410798104967356
# rmse= 1.1580500034526728
# fcp = 0.5243523686382036
#
# Iteration time: 0.20458745956420898 seconds
# Iteration: 148
# Estimating biases using als...
# mae = 0.6619194265239512
# mse = 0.8129434341966436
# rmse= 0.9016337583501649
# fcp = 0.6557113190679382
#
# Iteration time: 0.102935791015625 seconds
# Iteration: 149
# Estimating biases using als...
# mae = 0.6619991526953822
# mse = 0.8129850095584382
# rmse= 0.9016568136261369
# fcp = 0.654578836233301
#
# Iteration time: 0.13576245307922363 seconds
# Iteration: 150
# Estimating biases using als...
# mae = 0.659657898083446
# mse = 0.8213818901099068
# rmse= 0.9063012137859613
# fcp = 0.6576660297997636
#
# Iteration time: 0.16288161277770996 seconds
# Iteration: 151
# Estimating biases using als...
# mae = 0.6597286047562224
# mse = 0.8165813472680757
# rmse= 0.9036489070806625
# fcp = 0.6577218361668342
#
# Iteration time: 0.1643965244293213 seconds
# Iteration: 152
# Estimating biases using als...
# mae = 0.6641892070605917
# mse = 0.8155325752624477
# rmse= 0.9030684222485291
# fcp = 0.6483420608717219
#
# Iteration time: 0.15885210037231445 seconds
# Iteration: 153
# Estimating biases using als...
# mae = 0.6622970871951782
# mse = 0.8128154060314209
# rmse= 0.9015627576777009
# fcp = 0.6574818784170318
#
# Iteration time: 0.1517961025238037 seconds
# Iteration: 154
# Estimating biases using als...
# mae = 0.6623192478790547
# mse = 0.8132007379760955
# rmse= 0.9017764345868079
# fcp = 0.6549178131246225
#
# Iteration time: 0.16903114318847656 seconds
# Iteration: 155
# Estimating biases using als...
# mae = 0.6622328638972591
# mse = 0.8129768407461632
# rmse= 0.9016522837248089
# fcp = 0.6548500137795287
#
# Iteration time: 0.16103720664978027 seconds
# Iteration: 156
# Estimating biases using als...
# mae = 0.6598893708932841
# mse = 0.8156849457881722
# rmse= 0.9031527809779318
# fcp = 0.6576246276840211
#
# Iteration time: 0.24706268310546875 seconds
# Iteration: 157
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# mae = 0.8031553756231441
# mse = 1.1096309288890729
# rmse= 1.0533902073254113
# fcp = 0.6766933260385998
#
# Iteration time: 1.3417375087738037 seconds
# Iteration: 158
# Estimating biases using als...
# mae = 0.6625544922317048
# mse = 0.812813287879143
# rmse= 0.9015615829654361
# fcp = 0.6564985257372621
#
# Iteration time: 0.10341143608093262 seconds
# Iteration: 159
# Estimating biases using als...
# mae = 0.6620440952708837
# mse = 0.8128510853882565
# rmse= 0.9015825449664919
# fcp = 0.655440594281689
#
# Iteration time: 0.10314798355102539 seconds
# Iteration: 160
# Estimating biases using als...
# mae = 0.6595407555867111
# mse = 0.8177954056755676
# rmse= 0.9043204109581778
# fcp = 0.6587398729381593
#
# Iteration time: 0.10672640800476074 seconds
# Iteration: 161
# Estimating biases using als...
# mae = 0.6621739657851473
# mse = 0.8127649986889799
# rmse= 0.9015348017070555
# fcp = 0.655440594281689
#
# Iteration time: 0.09195590019226074 seconds
# Iteration: 162
# Estimating biases using als...
# mae = 0.6649056669519814
# mse = 0.8155815296904535
# rmse= 0.9030955263373047
# fcp = 0.6491118163216778
#
# Iteration time: 0.09262371063232422 seconds
# Iteration: 163
# Estimating biases using als...
# mae = 0.6617501661462292
# mse = 0.8359666709946331
# rmse= 0.9143121299614443
# fcp = 0.6636947656815955
#
# Iteration time: 0.1500873565673828 seconds
# Iteration: 164
# Estimating biases using als...
# mae = 0.6623834696077453
# mse = 0.8129316268681881
# rmse= 0.9016272105854992
# fcp = 0.6567012448494549
#
# Iteration time: 0.14270734786987305 seconds
# Iteration: 165
# Estimating biases using als...
# mae = 0.6643819082744006
# mse = 0.8150614353673776
# rmse= 0.9028075295251905
# fcp = 0.6481374481232011
#
# Iteration time: 0.16366052627563477 seconds
# Iteration: 166
# Estimating biases using als...
# mae = 0.6597664959467411
# mse = 0.8153859725752319
# rmse= 0.9029872493979259
# fcp = 0.6586405326543509
#
# Iteration time: 0.16524004936218262 seconds
# Iteration: 167
# Estimating biases using als...
# mae = 0.6617247859325276
# mse = 0.81228116496251
# rmse= 0.9012664228531484
# fcp = 0.6576842705332258
#
# Iteration time: 0.1401975154876709 seconds
# Iteration: 168
# Estimating biases using als...
# mae = 0.6596545641817064
# mse = 0.8141189682527012
# rmse= 0.9022854139642851
# fcp = 0.6612625926047245
#
# Iteration time: 0.14812707901000977 seconds
# Iteration: 169
# Estimating biases using als...
# mae = 0.6594900750450735
# mse = 0.8194797282368617
# rmse= 0.9052511962084677
# fcp = 0.657529821929946
#
# Iteration time: 0.08608341217041016 seconds
# Iteration: 170
# Estimating biases using als...
# mae = 0.6658046826151316
# mse = 0.8169022562290823
# rmse= 0.9038264524946602
# fcp = 0.6495887272270326
#
# Iteration time: 0.17061400413513184 seconds
# Iteration: 171
# Estimating biases using als...
# mae = 0.664149213568195
# mse = 0.8147726781160115
# rmse= 0.9026475935358226
# fcp = 0.6486831261121032
#
# Iteration time: 0.10489702224731445 seconds
# Iteration: 172
# Estimating biases using als...
# mae = 0.6651579906655258
# mse = 0.8131745432601173
# rmse= 0.9017619105174698
# fcp = 0.6535823839750163
#
# Iteration time: 0.1044776439666748 seconds
# Iteration: 173
# Estimating biases using als...
# mae = 0.6657780374711666
# mse = 0.8137238280221006
# rmse= 0.9020664210700344
# fcp = 0.6515557283467641
#
# Iteration time: 0.10315155982971191 seconds
# Iteration: 174
# Estimating biases using als...
# mae = 0.6596429081155889
# mse = 0.8141302146406864
# rmse= 0.9022916461104393
# fcp = 0.6612625926047245
#
# Iteration time: 0.09999752044677734 seconds
# Iteration: 175
# Estimating biases using sgd...
# mae = 0.8294470922629847
# mse = 1.1803829995941688
# rmse= 1.0864543246700107
# fcp = 0.6138933254105481
#
# Iteration time: 0.10191893577575684 seconds
# Iteration: 176
# Estimating biases using als...
# mae = 0.6712544522267518
# mse = 0.8233585232240294
# rmse= 0.9073910530879338
# fcp = 0.6514406469703743
#
# Iteration time: 0.09384393692016602 seconds
# Iteration: 177
# Estimating biases using als...
# mae = 0.661591522920568
# mse = 0.812288766239556
# rmse= 0.9012706398410835
# fcp = 0.6574818784170318
#
# Iteration time: 0.0912942886352539 seconds
# Iteration: 178
# mae = 0.7928358024617346
# mse = 1.0821845575584843
# rmse= 1.0402809993258957
# fcp = 0.6759123829086466
#
# Iteration time: 0.771862268447876 seconds
# Iteration: 179
# Estimating biases using als...
# mae = 0.6591563518279945
# mse = 0.8168636898104403
# rmse= 0.9038051171632302
# fcp = 0.6612438661976969
#
# Iteration time: 0.09278154373168945 seconds
# Iteration: 180
# mae = 0.7009598735536389
# mse = 0.8603047915812491
# rmse= 0.9275261675991945
# fcp = 0.6537725653266135
#
# Iteration time: 0.39879584312438965 seconds
# Iteration: 181
# Estimating biases using als...
# mae = 0.6628238732995038
# mse = 0.8132005957525654
# rmse= 0.9017763557293823
# fcp = 0.6549853027801396
#
# Iteration time: 0.14452219009399414 seconds
# Iteration: 182
# Estimating biases using als...
# mae = 0.663777492689859
# mse = 0.8145267268049103
# rmse= 0.9025113444189554
# fcp = 0.6501086276098245
#
# Iteration time: 0.16106629371643066 seconds
# Iteration: 183
# Estimating biases using als...
# mae = 0.6608767891725793
# mse = 0.8139948719752844
# rmse= 0.9022166435924824
# fcp = 0.6543508838157325
#
# Iteration time: 0.14991044998168945 seconds
# Iteration: 184
# Estimating biases using als...
# mae = 0.6624998350327369
# mse = 0.812798537175626
# rmse= 0.9015534022872
# fcp = 0.6574818784170318
#
# Iteration time: 0.13737988471984863 seconds
# Iteration: 185
# Estimating biases using als...
# mae = 0.6613886935508146
# mse = 0.8160846407897063
# rmse= 0.9033740315006328
# fcp = 0.650065743999502
#
# Iteration time: 0.1416018009185791 seconds
# Iteration: 186
# Estimating biases using als...
# mae = 0.6621640150865111
# mse = 0.812207627145127
# rmse= 0.9012256249936123
# fcp = 0.6587558146661222
#
# Iteration time: 0.1573500633239746 seconds
# Iteration: 187
# Estimating biases using als...
# mae = 0.6618764984143622
# mse = 0.8123495216553955
# rmse= 0.9013043446335958
# fcp = 0.6591610274153188
#
# Iteration time: 0.1516416072845459 seconds
# Iteration: 188
# Estimating biases using als...
# mae = 0.6599543213691795
# mse = 0.8135023802949813
# rmse= 0.9019436680275444
# fcp = 0.6595410950419351
#
# Iteration time: 0.13205814361572266 seconds
# Iteration: 189
# Estimating biases using als...
# mae = 0.6602555314693097
# mse = 0.817071250367491
# rmse= 0.9039199358170451
# fcp = 0.6518291942237359
#
# Iteration time: 0.14008069038391113 seconds
# Iteration: 190
# Estimating biases using als...
# mae = 0.6652113350028737
# mse = 0.8132106324002225
# rmse= 0.9017819206439118
# fcp = 0.6537175301894671
#
# Iteration time: 0.11014485359191895 seconds
# Iteration: 191
# Estimating biases using als...
# mae = 0.6631004883699694
# mse = 0.8133812841810056
# rmse= 0.9018765348876783
# fcp = 0.6517801156552637
#
# Iteration time: 0.08583259582519531 seconds
# Iteration: 192
# Estimating biases using als...
# mae = 0.6694439782324854
# mse = 0.8228854654672288
# rmse= 0.9071303464592224
# fcp = 0.6480480634684262
#
# Iteration time: 0.1205897331237793 seconds
# Iteration: 193
# Estimating biases using als...
# mae = 0.6606083962501927
# mse = 0.8135267310164923
# rmse= 0.9019571669522297
# fcp = 0.6554837206593278
#
# Iteration time: 0.10448479652404785 seconds
# Iteration: 194
# Estimating biases using als...
# mae = 0.6673856928040701
# mse = 0.8158414940791645
# rmse= 0.9032394444880961
# fcp = 0.6511620777338484
#
# Iteration time: 0.12082982063293457 seconds
# Iteration: 195
# Estimating biases using als...
# mae = 0.6621542042402103
# mse = 0.8122294461767179
# rmse= 0.9012377301116048
# fcp = 0.6588902709883699
#
# Iteration time: 0.08915328979492188 seconds
# Iteration: 196
# Estimating biases using als...
# mae = 0.6595617788485606
# mse = 0.8142363454214917
# rmse= 0.902350455987856
# fcp = 0.6618031656243015
#
# Iteration time: 0.19501256942749023 seconds
# Iteration: 197
# Estimating biases using als...
# mae = 0.6665560758805055
# mse = 0.8147518799136393
# rmse= 0.9026360727965835
# fcp = 0.6498257200513667
#
# Iteration time: 0.11018872261047363 seconds
# Iteration: 198
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# mae = 0.7704261017262387
# mse = 1.055004050606433
# rmse= 1.0271339010111744
# fcp = 0.5071067415267254
#
# Iteration time: 0.27887892723083496 seconds
# Iteration: 199
# Estimating biases using als...
# mae = 0.6623832080251922
# mse = 0.8127145467488576
# rmse= 0.9015068201344112
# fcp = 0.6574818784170318
#
# Iteration time: 0.16498780250549316 seconds
# Iteration: 200
# Estimating biases using als...
# mae = 0.6643187400782067
# mse = 0.816196996403214
# rmse= 0.9034362160126269
# fcp = 0.6488877916567223
#
# Iteration time: 0.1322460174560547 seconds
# Iteration: 201
# Estimating biases using als...
# mae = 0.6632700632807453
# mse = 0.8126995974240454
# rmse= 0.9014985287974936
# fcp = 0.658056196021728
#
# Iteration time: 0.11571741104125977 seconds
# Iteration: 202
# Estimating biases using als...
# mae = 0.6623130504433958
# mse = 0.8122047637599199
# rmse= 0.9012240363860253
# fcp = 0.6585541432391514
#
# Iteration time: 0.14732003211975098 seconds
# Iteration: 203
# Estimating biases using als...
# mae = 0.6628068641294247
# mse = 0.8127333301178495
# rmse= 0.9015172378373303
# fcp = 0.6577587842392586
#
# Iteration time: 0.09041810035705566 seconds
# Iteration: 204
# Estimating biases using als...
# mae = 0.6643779793499932
# mse = 0.8139387523474474
# rmse= 0.9021855420851341
# fcp = 0.6509816269174006
#
# Iteration time: 0.10433411598205566 seconds
# Iteration: 205
# Estimating biases using als...
# mae = 0.6597981364928603
# mse = 0.8151332480127298
# rmse= 0.9028473004958977
# fcp = 0.6585050536025103
#
# Iteration time: 0.10499167442321777 seconds
# Iteration: 206
# Estimating biases using als...
# mae = 0.6620380616309526
# mse = 0.8122150637728756
# rmse= 0.901229750825435
# fcp = 0.6573469595237494
#
# Iteration time: 0.12432622909545898 seconds
# Iteration: 207
# Estimating biases using als...
# mae = 0.6627816275138171
# mse = 0.8122463222837908
# rmse= 0.9012470928018524
# fcp = 0.6582852723722983
#
# Iteration time: 0.09041428565979004 seconds
# Iteration: 208
# Estimating biases using als...
# mae = 0.6628137726979529
# mse = 0.8122276194163667
# rmse= 0.9012367166379578
# fcp = 0.6580164293518881
#
# Iteration time: 0.10323429107666016 seconds
# Iteration: 209
# Estimating biases using sgd...
# mae = 0.6898462847511149
# mse = 0.841477941869677
# rmse= 0.9173210680397986
# fcp = 0.6761487016368696
#
# Iteration time: 0.10122823715209961 seconds
# Iteration: 210
# Estimating biases using als...
# mae = 0.6605382383478127
# mse = 0.8311869037159448
# rmse= 0.9116945232455578
# fcp = 0.6633540727393412
#
# Iteration time: 0.1820693016052246 seconds
# Iteration: 211
# Estimating biases using als...
# mae = 0.6647012125863333
# mse = 0.8138234377793238
# rmse= 0.9021216313664825
# fcp = 0.6526141922220599
#
# Iteration time: 0.08747577667236328 seconds
# Iteration: 212
# Estimating biases using als...
# mae = 0.6604519665473113
# mse = 0.8136863215549742
# rmse= 0.9020456316367672
# fcp = 0.6556193027929056
#
# Iteration time: 0.09666895866394043 seconds
# Iteration: 213
# Estimating biases using als...
# mae = 0.6628894589661561
# mse = 0.8122296675288387
# rmse= 0.9012378529161094
# fcp = 0.6580164293518881
#
# Iteration time: 0.10222887992858887 seconds
# Iteration: 214
# Estimating biases using als...
# mae = 0.6654431637089488
# mse = 0.813375228506562
# rmse= 0.9018731776178743
# fcp = 0.6536499561262051
#
# Iteration time: 0.1263570785522461 seconds
# Iteration: 215
# Estimating biases using als...
# mae = 0.6609615799623771
# mse = 0.8339951289929098
# rmse= 0.9132333376486591
# fcp = 0.6639673564925365
#
# Iteration time: 0.09606122970581055 seconds
# Iteration: 216
# Estimating biases using als...
# mae = 0.663918917517919
# mse = 0.8135554064988948
# rmse= 0.9019730630672375
# fcp = 0.6517801156552637
#
# Iteration time: 0.08644747734069824 seconds
# Iteration: 217
# Estimating biases using als...
# mae = 0.6653142265452298
# mse = 0.8132818207923629
# rmse= 0.9018213907378572
# fcp = 0.6542832162777599
#
# Iteration time: 0.10132455825805664 seconds
# Iteration: 218
# Estimating biases using als...
# mae = 0.6620563790001432
# mse = 0.8152562207828377
# rmse= 0.9029154006787334
# fcp = 0.6489071988065034
#
# Iteration time: 0.19711875915527344 seconds
# Iteration: 219
# mae = 0.8275021686545491
# mse = 1.1686845098897836
# rmse= 1.081057126099164
# fcp = 0.6566695946793826
#
# Iteration time: 1.7600739002227783 seconds
# Iteration: 220
# Estimating biases using als...
# mae = 0.6622114878626165
# mse = 0.8354724177334687
# rmse= 0.9140418030557841
# fcp = 0.6627157177647068
#
# Iteration time: 0.19681501388549805 seconds
# Iteration: 221
# Estimating biases using als...
# mae = 0.6632749608762611
# mse = 0.8127500493456616
# rmse= 0.9015265106172207
# fcp = 0.6570844422714127
#
# Iteration time: 0.17624163627624512 seconds
# Iteration: 222
# Estimating biases using als...
# mae = 0.6643126893700799
# mse = 0.8130056262913369
# rmse= 0.9016682462476634
# fcp = 0.6538319775319397
#
# Iteration time: 0.17472600936889648 seconds
# Iteration: 223
# Estimating biases using als...
# mae = 0.6639311780840191
# mse = 0.8127563380897097
# rmse= 0.9015299984413773
# fcp = 0.6548136730328464
#
# Iteration time: 0.09584331512451172 seconds
# Iteration: 224
# Estimating biases using als...
# mae = 0.6647001905666426
# mse = 0.8136471936375859
# rmse= 0.9020239429403112
# fcp = 0.6520717389364494
#
# Iteration time: 0.1027069091796875 seconds
# Iteration: 225
# Estimating biases using als...
# mae = 0.6684898112223228
# mse = 0.816201360668528
# rmse= 0.903438631379314
# fcp = 0.6517812508869906
#
# Iteration time: 0.1111593246459961 seconds
# Iteration: 226
# mae = 0.9348838878569271
# mse = 1.4280347046951811
# rmse= 1.195004060535018
# fcp = 0.49593394219942455
#
# Iteration time: 0.3398864269256592 seconds
# Iteration: 227
# Estimating biases using als...
# mae = 0.6625566104914783
# mse = 0.8121987544843582
# rmse= 0.9012207024277451
# fcp = 0.6582852723722983
#
# Iteration time: 0.14773344993591309 seconds
# Iteration: 228
# Estimating biases using als...
# mae = 0.6628505694169922
# mse = 0.8122379597622427
# rmse= 0.9012424533732544
# fcp = 0.6580836374966232
#
# Iteration time: 0.16054177284240723 seconds
# Iteration: 229
# Estimating biases using als...
# mae = 0.6653536771618059
# mse = 0.8133088283661513
# rmse= 0.9018363645175056
# fcp = 0.6537175301894671
#
# Iteration time: 0.16910457611083984 seconds
# Iteration: 230
# Estimating biases using als...
# mae = 0.6657507276639572
# mse = 0.8151810129362235
# rmse= 0.9028737524904705
# fcp = 0.6496521011289634
#
# Iteration time: 0.1354656219482422 seconds
# Iteration: 231
# Estimating biases using als...
# mae = 0.6600605484699109
# mse = 0.8134401666413125
# rmse= 0.901909178709981
# fcp = 0.6590675554733663
#
# Iteration time: 0.15611958503723145 seconds
# Iteration: 232
# Estimating biases using als...
# mae = 0.6640848828157052
# mse = 0.8134878236108922
# rmse= 0.90193559837213
# fcp = 0.651508536608022
#
# Iteration time: 0.1473982334136963 seconds
# Iteration: 233
# Estimating biases using als...
# mae = 0.6721214716860405
# mse = 0.8245478997756129
# rmse= 0.9080461991416587
# fcp = 0.6516443220321271
#
# Iteration time: 0.16748380661010742 seconds
# Iteration: 234
# Estimating biases using als...
# mae = 0.6603663005545855
# mse = 0.8129999857715814
# rmse= 0.9016651184179088
# fcp = 0.6588646382672134
#
# Iteration time: 0.1523149013519287 seconds
# Iteration: 235
# Estimating biases using als...
# mae = 0.6597872859634094
# mse = 0.8156929942213923
# rmse= 0.9031572367098613
# fcp = 0.6587760194175322
#
# Iteration time: 0.12191915512084961 seconds
# Iteration: 236
# Estimating biases using als...
# mae = 0.6624818979934074
# mse = 0.8353444066134899
# rmse= 0.9139717756109812
# fcp = 0.6600408451769567
#
# Iteration time: 0.21936774253845215 seconds
# Iteration: 237
# Estimating biases using als...
# mae = 0.6641696949856786
# mse = 0.8130399982853237
# rmse= 0.9016873062682671
# fcp = 0.6548665818907419
#
# Iteration time: 0.10813188552856445 seconds
# Iteration: 238
# Estimating biases using als...
# mae = 0.6607706506254035
# mse = 0.813426977223837
# rmse= 0.9019018667370842
# fcp = 0.6550770216359453
#
# Iteration time: 0.10612201690673828 seconds
# Iteration: 239
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# mae = 0.8031553756231441
# mse = 1.1096309288890729
# rmse= 1.0533902073254113
# fcp = 0.6766933260385998
#
# Iteration time: 1.264573097229004 seconds
# Iteration: 240
# Estimating biases using als...
# mae = 0.6678287821280624
# mse = 0.8155626398996526
# rmse= 0.9030850679197684
# fcp = 0.6539458270550182
#
# Iteration time: 0.1601405143737793 seconds
# Iteration: 241
# Estimating biases using als...
# mae = 0.663055660536252
# mse = 0.8131584564856675
# rmse= 0.9017529908382159
# fcp = 0.654917666271361
#
# Iteration time: 0.2131953239440918 seconds
# Iteration: 242
# Estimating biases using als...
# mae = 0.6617955648810844
# mse = 0.8359090407765148
# rmse= 0.9142806138032867
# fcp = 0.6648070945657472
#
# Iteration time: 0.18014860153198242 seconds
# Iteration: 243
# Estimating biases using als...
# mae = 0.6618757843504655
# mse = 0.8122333427335312
# rmse= 0.901239891889796
# fcp = 0.6574144180520226
#
# Iteration time: 0.167158842086792 seconds
# Iteration: 244
# Estimating biases using als...
# mae = 0.6614437757236198
# mse = 0.8364814456244299
# rmse= 0.9145935958798476
# fcp = 0.6645808043345521
#
# Iteration time: 0.1705012321472168 seconds
# Iteration: 245
# Estimating biases using als...
# mae = 0.6646722583785656
# mse = 0.8138879027715489
# rmse= 0.9021573603155654
# fcp = 0.6515448559147488
#
# Iteration time: 0.16797566413879395 seconds
# Iteration: 246
# Estimating biases using als...
# mae = 0.6682421707777632
# mse = 0.822931771975922
# rmse= 0.9071558697246698
# fcp = 0.6485934751627357
#
# Iteration time: 0.14877557754516602 seconds
# Iteration: 247
# Estimating biases using als...
# mae = 0.6657986118640907
# mse = 0.8137632657596006
# rmse= 0.9020882804690462
# fcp = 0.6516234851016006
#
# Iteration time: 0.11242175102233887 seconds
# Iteration: 248
# Estimating biases using als...
# mae = 0.6614077007991033
# mse = 0.816031888938907
# rmse= 0.9033448339028164
# fcp = 0.650065743999502
#
# Iteration time: 0.10499095916748047 seconds
# Iteration: 249
# Estimating biases using sgd...
# mae = 0.897773169016745
# mse = 1.3503159947434942
# rmse= 1.1620309783923553
# fcp = 0.6132076851175928
#
# Iteration time: 0.12996673583984375 seconds
# Iteration: 250
# Estimating biases using als...
# mae = 0.6634928813127846
# mse = 0.813317392013258
# rmse= 0.9018411123991066
# fcp = 0.6516443220321271
#
# Iteration time: 0.1821918487548828 seconds
# Iteration: 251
# Estimating biases using als...
# mae = 0.6648809708223409
# mse = 0.8129955979038467
# rmse= 0.9016626852120735
# fcp = 0.6526139330181286
#
# Iteration time: 0.1191401481628418 seconds
# Iteration: 252
# Estimating biases using als...
# mae = 0.6614661187351187
# mse = 0.8341862561366384
# rmse= 0.9133379747588722
# fcp = 0.6644669587864792
#
# Iteration time: 0.11666035652160645 seconds
# Iteration: 253
# Estimating biases using als...
# mae = 0.660497420563258
# mse = 0.8128545084890999
# rmse= 0.9015844433490964
# fcp = 0.6585264806800322
#
# ...
# Iteration: 416
# Estimating biases using als...
# mae = 0.6661485231352481
# mse = 0.8142742397112261
# rmse= 0.9023714532891797
# fcp = 0.6483115600798747
#
# Iteration time: 0.2943732738494873 seconds
# Iteration: 417
# Estimating biases using als...
# mae = 0.66039020347781
# mse = 0.813907484157202
# rmse= 0.9021682127836261
# fcp = 0.6552803622650301
#
# Iteration time: 0.16956663131713867 seconds
# Iteration: 418
# Estimating biases using als...
# mae = 0.662120303308068
# mse = 0.8122119633588442
# rmse= 0.9012280307218835
# fcp = 0.6592264422628688
#
# Iteration time: 0.1768651008605957 seconds
# Iteration: 419
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# mae = 0.7704261017262387
# mse = 1.055004050606433
# rmse= 1.0271339010111744
# fcp = 0.5071067415267254
#
# Iteration time: 0.3845071792602539 seconds
# Iteration: 420
# Estimating biases using als...
# mae = 0.6658521613849322
# mse = 0.831616696479825
# rmse= 0.9119302037326239
# fcp = 0.6569633354156181
#
# Iteration time: 0.1671607494354248 seconds
# Iteration: 421
# Estimating biases using als...
# mae = 0.6622334085822236
# mse = 0.8135811602893093
# rmse= 0.9019873393176365
# fcp = 0.6523947248408226
#
# Iteration time: 0.187636137008667 seconds
# Iteration: 422
# Estimating biases using als...
# mae = 0.6661049819986449
# mse = 0.8165115740702622
# rmse= 0.9036102998916414
# fcp = 0.6502246529367165
#
# Iteration time: 0.18767094612121582 seconds
# Iteration: 423
# Estimating biases using als...
# mae = 0.6615248174842504
# mse = 0.816598459287467
# rmse= 0.9036583753208217
# fcp = 0.6492971821602499
#
# Iteration time: 0.15960478782653809 seconds
# Iteration: 424
# Estimating biases using als...
# mae = 0.6593930395101368
# mse = 0.8187258387987827
# rmse= 0.9048347024726575
# fcp = 0.6592830078694258
#
# Iteration time: 0.20007085800170898 seconds
# Iteration: 425
# Estimating biases using als...
# mae = 0.6660807685898601
# mse = 0.813938980713163
# rmse= 0.9021856686476254
# fcp = 0.6510814870349111
#
# Iteration time: 0.09692621231079102 seconds
# Iteration: 426
# Estimating biases using als...
# mae = 0.6681007694585233
# mse = 0.8231403969424377
# rmse= 0.9072708509273499
# fcp = 0.6490026258514757
#
# Iteration time: 0.10485482215881348 seconds
# Iteration: 427
# Estimating biases using als...
# mae = 0.6624890198163651
# mse = 0.8121952613387892
# rmse= 0.9012187644178239
# fcp = 0.6584197043246491
#
# Iteration time: 0.10203933715820312 seconds
# Iteration: 428
# Estimating biases using als...
# mae = 0.6637094580731744
# mse = 0.8138091649933101
# rmse= 0.9021137206546136
# fcp = 0.6511176558486252
#
# Iteration time: 0.10792994499206543 seconds
# Iteration: 429
# Estimating biases using als...
# mae = 0.6595933328736763
# mse = 0.8141996248975468
# rmse= 0.9023301086063497
# fcp = 0.6613977248120025
#
# Iteration time: 0.1007852554321289 seconds
# Iteration: 430
# Estimating biases using sgd...
# mae = 0.9252435686584555
# mse = 1.4106662308682136
# rmse= 1.187714709376041
# fcp = 0.6101937999992116
#
# Iteration time: 0.22480201721191406 seconds
# Iteration: 431
# Estimating biases using als...
# mae = 0.6642821791327719
# mse = 0.8133931415219297
# rmse= 0.9018831085689152
# fcp = 0.6516443220321271
#
# Iteration time: 0.09859323501586914 seconds
# Iteration: 432
# Estimating biases using als...
# mae = 0.659162563331346
# mse = 0.8163275227392326
# rmse= 0.903508451946761
# fcp = 0.6609731777959723
#
# Iteration time: 0.10881447792053223 seconds
# Iteration: 433
# mae = 0.7915166091086291
# mse = 1.074400320246525
# rmse= 1.0365328360676882
# fcp = 0.6716294333104708
#
# Iteration time: 0.881230354309082 seconds
# Iteration: 434
# Estimating biases using als...
# mae = 0.6611791304371852
# mse = 0.8133443668035628
# rmse= 0.9018560676757477
# fcp = 0.6550534177656641
#
# Iteration time: 0.09536957740783691 seconds
# Iteration: 435
# Estimating biases using als...
# mae = 0.6637500233106179
# mse = 0.8138446932909192
# rmse= 0.9021334121353223
# fcp = 0.6499723836827016
#
# Iteration time: 0.09456253051757812 seconds
# Iteration: 436
# mae = 0.8442236766615955
# mse = 1.2219202012499353
# rmse= 1.1054049942215456
# fcp = 0.5253577879672086
#
# Iteration time: 0.3477964401245117 seconds
# Iteration: 437
# Estimating biases using als...
# mae = 0.6664197765344084
# mse = 0.8142085437942574
# rmse= 0.9023350507401657
# fcp = 0.6512169745584677
#
# Iteration time: 0.11656975746154785 seconds
# Iteration: 438
# Estimating biases using als...
# mae = 0.6622377078457135
# mse = 0.8334568345531952
# rmse= 0.9129385710732104
# fcp = 0.6602448732595687
#
# Iteration time: 0.2007913589477539 seconds
# Iteration: 439
# Estimating biases using als...
# mae = 0.6605751480319647
# mse = 0.8136989520311603
# rmse= 0.9020526326280304
# fcp = 0.6553481464224352
#
# Iteration time: 0.13821840286254883 seconds
# Iteration: 440
# Estimating biases using als...
# mae = 0.665123836238049
# mse = 0.8136096057385699
# rmse= 0.9020031073885333
# fcp = 0.6518683521228447
#
# Iteration time: 0.14559125900268555 seconds
# Iteration: 441
# Estimating biases using als...
# mae = 0.6688821312699893
# mse = 0.8229460477659292
# rmse= 0.9071637381233496
# fcp = 0.6481844032633883
#
# Iteration time: 0.1539602279663086 seconds
# Iteration: 442
# Estimating biases using als...
# mae = 0.6658040745338216
# mse = 0.8136507275162685
# rmse= 0.902025901798983
# fcp = 0.6540133011539925
#
# Iteration time: 0.1535477638244629 seconds
# Iteration: 443
# Estimating biases using als...
# mae = 0.6687045049485881
# mse = 0.8164475762309219
# rmse= 0.9035748868969975
# fcp = 0.6518489061690835
#
# Iteration time: 0.12794709205627441 seconds
# Iteration: 444
# Estimating biases using als...
# mae = 0.6592307453574555
# mse = 0.8158297178311965
# rmse= 0.9032329255685914
# fcp = 0.6599957474051619
#
# Iteration time: 0.10857582092285156 seconds
# Iteration: 445
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# mae = 0.7726448267576927
# mse = 1.0614245004213367
# rmse= 1.0302545803932817
# fcp = 0.49477520579373563
#
# Iteration time: 0.19586443901062012 seconds
# Iteration: 446
# Estimating biases using als...
# mae = 0.6659042414176402
# mse = 0.8156800888510543
# rmse= 0.9031500920949155
# fcp = 0.6487031197805275
#
# Iteration time: 0.1035773754119873 seconds
# Iteration: 447
# Estimating biases using als...
# mae = 0.6672163614049795
# mse = 0.8225401170583214
# rmse= 0.9069399743413681
# fcp = 0.6516286221362946
#
# Iteration time: 0.11843681335449219 seconds
# Iteration: 448
# Estimating biases using als...
# mae = 0.6651710693507923
# mse = 0.8139134635801611
# rmse= 0.9021715266955398
# fcp = 0.6518683521228447
#
# Iteration time: 0.11070799827575684 seconds
# Iteration: 449
# Estimating biases using als...
# mae = 0.6597342263443596
# mse = 0.8229290893232295
# rmse= 0.9071543911172064
# fcp = 0.6572131593384694
#
# Iteration time: 0.10725617408752441 seconds
# Iteration: 450
# Estimating biases using als...
# mae = 0.6687086994002343
# mse = 0.8230051189139853
# rmse= 0.9071962956901805
# fcp = 0.64791173242447
#
# Iteration time: 0.12484526634216309 seconds
# Iteration: 451
# Estimating biases using als...
# mae = 0.666409330237638
# mse = 0.8144284998103958
# rmse= 0.9024569240747149
# fcp = 0.6505582681498095
#
# Iteration time: 0.09876275062561035 seconds
# Iteration: 452
# Estimating biases using als...
# mae = 0.6646089410263235
# mse = 0.8145907039212849
# rmse= 0.9025467876632683
# fcp = 0.6503322106028246
#
# Iteration time: 0.1010289192199707 seconds
# Iteration: 453
# Estimating biases using sgd...
# mae = 0.7453506877932016
# mse = 0.9656080019809966
# rmse= 0.9826535513501168
# fcp = 0.6495121512514918
#
# Iteration time: 0.12610483169555664 seconds
# Iteration: 454
# Estimating biases using als...
# mae = 0.6596553323413977
# mse = 0.8140008739196081
# rmse= 0.9022199698075897
# fcp = 0.6600823964417022
#
# Iteration time: 0.10707950592041016 seconds
# Iteration: 455
# Estimating biases using als...
# mae = 0.6643647873242614
# mse = 0.8129754138239996
# rmse= 0.9016514924426176
# fcp = 0.6535612463309535
#
# Iteration time: 0.1242361068725586 seconds
# Iteration: 456
# Estimating biases using als...
# mae = 0.6621178553899512
# mse = 0.8347832699627684
# rmse= 0.9136647470285633
# fcp = 0.6622401637388107
#
# Iteration time: 0.20650792121887207 seconds
# Iteration: 457
# Estimating biases using als...
# mae = 0.6687967597419785
# mse = 0.8165511599076402
# rmse= 0.9036322038902997
# fcp = 0.6518489061690835
#
# Iteration time: 0.17600226402282715 seconds
# Iteration: 458
# mae = 0.8230295196773281
# mse = 1.1580697650157104
# rmse= 1.076136499248915
# fcp = 0.6886101154174473
#
# Iteration time: 1.2256004810333252 seconds
# Iteration: 459
# Estimating biases using als...
# mae = 0.6606258841393396
# mse = 0.8127555604681984
# rmse= 0.9015295671624965
# fcp = 0.6581207538613153
#
# Iteration time: 0.1276867389678955 seconds
# Iteration: 460
# Estimating biases using als...
# mae = 0.6603394122852358
# mse = 0.8202005054415956
# rmse= 0.9056492176563703
# fcp = 0.6535315527939398
#
# Iteration time: 0.1246180534362793 seconds
# Iteration: 461
# mae = 0.7396744266479818
# mse = 0.9644683075176611
# rmse= 0.9820734735841616
# fcp = 0.5923310495409189
#
# Iteration time: 0.2093968391418457 seconds
# Iteration: 462
# Estimating biases using als...
# mae = 0.6627320938250795
# mse = 0.812709669678549
# rmse= 0.9015041151756041
# fcp = 0.6578262284881757
#
# Iteration time: 0.180922269821167 seconds
# Iteration: 463
# Estimating biases using als...
# mae = 0.6666985455479799
# mse = 0.8146288768989454
# rmse= 0.9025679347832746
# fcp = 0.6505582681498095
#
# Iteration time: 0.1567850112915039 seconds
# Iteration: 464
# Estimating biases using als...
# mae = 0.6595970040868845
# mse = 0.8163571706584916
# rmse= 0.9035248589045526
# fcp = 0.6580611323173752
#
# Iteration time: 0.16453266143798828 seconds
# Iteration: 465
# Estimating biases using als...
# mae = 0.6604332106858417
# mse = 0.81292340314491
# rmse= 0.90162265008423
# fcp = 0.6587293695692751
#
# Iteration time: 0.16781401634216309 seconds
# Iteration: 466
# Estimating biases using als...
# mae = 0.6661125803159088
# mse = 0.8154887365584188
# rmse= 0.903044149838987
# fcp = 0.6493801163910865
#
# Iteration time: 0.14119219779968262 seconds
# Iteration: 467
# Estimating biases using als...
# mae = 0.6614322676706607
# mse = 0.8365821118819099
# rmse= 0.9146486275515368
# fcp = 0.6645808043345521
#
# Iteration time: 0.1348435878753662 seconds
# Iteration: 468
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# mae = 0.8999521789070305
# mse = 1.3520665822226643
# rmse= 1.1627839791735455
# fcp = 0.6484353536099177
#
# Iteration time: 1.8740782737731934 seconds
# Iteration: 469
# Estimating biases using als...
# mae = 0.6606778543517413
# mse = 0.8153561648247897
# rmse= 0.9029707441688184
# fcp = 0.6507473802485334
#
# Iteration time: 0.2553868293762207 seconds
# Iteration: 470
# Estimating biases using als...
# mae = 0.6619241303656891
# mse = 0.8129703077743534
# rmse= 0.9016486609396996
# fcp = 0.6544432593594572
#
# Iteration time: 0.40050196647644043 seconds
# Iteration: 471
# Estimating biases using als...
# mae = 0.6665234791392304
# mse = 0.8145115183364072
# rmse= 0.9025029187412122
# fcp = 0.6504225482912332
#
# Iteration time: 0.2584106922149658 seconds
# Iteration: 472
# Estimating biases using als...
# mae = 0.6647963095034569
# mse = 0.8143350179136699
# rmse= 0.9024051295918424
# fcp = 0.6502641901630788
#
# Iteration time: 0.18435192108154297 seconds
# Iteration: 473
# Estimating biases using als...
# mae = 0.6605564714493354
# mse = 0.813757718931124
# rmse= 0.9020852060260849
# fcp = 0.6552803622650301
#
# Iteration time: 0.19520306587219238 seconds
# Iteration: 474
# Estimating biases using sgd...
# mae = 0.6891337125787834
# mse = 0.8396393339611704
# rmse= 0.9163183584110767
# fcp = 0.6731206380580262
#
# Iteration time: 0.22490453720092773 seconds
# Iteration: 475
# Estimating biases using als...
# mae = 0.6688431640669671
# mse = 0.8185007019433225
# rmse= 0.9047102861929461
# fcp = 0.6513411045557017
#
# Iteration time: 0.09958887100219727 seconds
# Iteration: 476
# Estimating biases using als...
# mae = 0.6611215921562881
# mse = 0.8124298719796043
# rmse= 0.9013489179999077
# fcp = 0.6584940043515167
#
# Iteration time: 0.13018512725830078 seconds
# Iteration: 477
# Estimating biases using als...
# mae = 0.668712344018405
# mse = 0.8164572053305648
# rmse= 0.9035802152164272
# fcp = 0.6518489061690835
#
# Iteration time: 0.14804434776306152 seconds
# Iteration: 478
# Estimating biases using als...
# mae = 0.6644503337460744
# mse = 0.8135087678736024
# rmse= 0.9019472090281129
# fcp = 0.652342949495889
#
# Iteration time: 0.13941383361816406 seconds
# Iteration: 479
# Estimating biases using als...
# mae = 0.6674336735667737
# mse = 0.8247864595597815
# rmse= 0.9081775484781495
# fcp = 0.6556602303769332
#
# Iteration time: 0.15720367431640625 seconds
# Iteration: 480
# Estimating biases using als...
# mae = 0.6609097157460018
# mse = 0.813232687448007
# rmse= 0.9017941491537894
# fcp = 0.655982074799919
#
# Iteration time: 0.1762714385986328 seconds
# Iteration: 481
# Estimating biases using als...
# mae = 0.6638543339818643
# mse = 0.8124829900056162
# rmse= 0.9013783833693907
# fcp = 0.6553069139471172
#
# Iteration time: 0.16653037071228027 seconds
# Iteration: 482
# mae = 0.7907428160185417
# mse = 1.0656596465935662
# rmse= 1.032307922372761
# fcp = 0.6742886918569453
#
# Iteration time: 0.90824294090271 seconds
# Iteration: 483
# Estimating biases using als...
# mae = 0.667923716311187
# mse = 0.8162546894925562
# rmse= 0.9034681452561325
# fcp = 0.6491761499762174
#
# Iteration time: 0.22452139854431152 seconds
# Iteration: 484
# Estimating biases using als...
# mae = 0.6633805660115539
# mse = 0.8134902856241116
# rmse= 0.9019369632208848
# fcp = 0.6517801156552637
#
# Iteration time: 0.10673761367797852 seconds
# Iteration: 485
# mae = 0.7575122186270711
# mse = 0.9965826183575511
# rmse= 0.9982898468669062
# fcp = 0.614238728791126
#
# Iteration time: 0.28598570823669434 seconds
# Iteration: 486
# Estimating biases using als...
# mae = 0.6597382880104287
# mse = 0.813879060836384
# rmse= 0.9021524598627352
# fcp = 0.66035309248217
#
# Iteration time: 0.10118484497070312 seconds
# Iteration: 487
# Estimating biases using als...
# mae = 0.6625356733719864
# mse = 0.8127755198107999
# rmse= 0.9015406368050194
# fcp = 0.657549340618852
#
# Iteration time: 0.1379833221435547 seconds
# Iteration: 488
# Estimating biases using als...
# mae = 0.6599278058360135
# mse = 0.8177446567432407
# rmse= 0.9042923513683175
# fcp = 0.6532590866581443
#
# Iteration time: 0.10674858093261719 seconds
# Iteration: 489
# Estimating biases using als...
# mae = 0.668930258358834
# mse = 0.817702699917582
# rmse= 0.9042691523642626
# fcp = 0.6504922405175879
#
# Iteration time: 0.12342643737792969 seconds
# Iteration: 490
# Estimating biases using als...
# mae = 0.661410883604676
# mse = 0.8364961260204883
# rmse= 0.9146016214836317
# fcp = 0.6644444684079942
#
# Iteration time: 0.11281347274780273 seconds
# Iteration: 491
# Estimating biases using als...
# mae = 0.6604581212666248
# mse = 0.8138189065163264
# rmse= 0.9021191199150622
# fcp = 0.6552125800815375
#
# Iteration time: 0.11543512344360352 seconds
# Iteration: 492
# Estimating biases using als...
# mae = 0.6625106300771513
# mse = 0.8353149877951976
# rmse= 0.9139556815268438
# fcp = 0.6601768618882714
#
# Iteration time: 0.11889529228210449 seconds
# Iteration: 493
# Estimating biases using als...
# mae = 0.6637917230485965
# mse = 0.8128039813079307
# rmse= 0.9015564215887605
# fcp = 0.6549488363669292
#
# Iteration time: 0.11146426200866699 seconds
# Iteration: 494
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# mae = 0.7704261017262387
# mse = 1.055004050606433
# rmse= 1.0271339010111744
# fcp = 0.5071067415267254
#
# Iteration time: 0.22607207298278809 seconds
# Iteration: 495
# Estimating biases using als...
# mae = 0.6607215326018508
# mse = 0.8126645436529699
# rmse= 0.9014790866420418
# fcp = 0.6589664712933321
#
# Iteration time: 0.10688519477844238 seconds
# Iteration: 496
# Estimating biases using als...
# mae = 0.6656291098629745
# mse = 0.8135141493835218
# rmse= 0.9019501922964049
# fcp = 0.6541482549701461
#
# Iteration time: 0.11451292037963867 seconds
# Iteration: 497
# Estimating biases using sgd...
# mae = 0.9081855110766694
# mse = 1.373269875043978
# rmse= 1.17186597998405
# fcp = 0.6106547152778912
#
# Iteration time: 0.11213874816894531 seconds
# Iteration: 498
# Estimating biases using als...
# mae = 0.6601893651485516
# mse = 0.8158847054269974
# rmse= 0.9032633643777419
# fcp = 0.6508155557643963
#
# Iteration time: 0.22299790382385254 seconds
# Iteration: 499
# Estimating biases using als...
# mae = 0.6649491549397448
# mse = 0.8143482982858261
# rmse= 0.9024124878822467
# fcp = 0.6512731915558793
#
# Iteration time: 0.11716365814208984 seconds

# %%
study.best_value
# Out:
# 0.8121952613387892

# %%
best_params = study.best_params
best_params
# Out:
# {'algo_type': 'BaselineOnly',
#  'method_type': 'als',
#  'reg_u': 0.5654833953301198,
#  'reg_i': 0.9980444259171931}
