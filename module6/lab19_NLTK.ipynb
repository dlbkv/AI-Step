# %% [markdown]
# <a href="https://colab.research.google.com/github/dlbkv/AI-Step/blob/master/module6/lab19_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1
# Проведіть токенизацію тексту:
#  * Розділіть текст на речення
#  * Кожне речення розділіть на слова. Результатом має бути `list[list]` де скажімо `data[5][10]` означає 10-те слово з 5-го речення(індексація з 0)
#  * Видаліть пунктуацію та стоп-слова
#  * Створіть список усіх слів з тексту 'words`

# %%
text = """Mrs Pig was very tired: 'Oh dear,' she said to her three little pigs, 'I can’t do this work anymore, I’m afraid you must leave home and make your own way in the world.' So the three little pigs set off.

The first little pig met a man carrying a bundle of straw.

'Excuse me,' said the first little pig politely. 'Would you please sell some of your straw so I can make a house?'

The man readily agreed and the first little pig went off to find a good place to build his house.

The other little pigs carried on along the road and, soon, they met a man carrying a bundle of sticks.

'Excuse me,' said the little pig politely. 'Would you please sell me some sticks so I can build a house?'

The man readily agreed and the little pig said goodbye to his brother.

The third little pig didn’t think much of their ideas:

'I’m going to build myself a much bigger, better, stronger house,' he thought, and he carried off down the road until he met a man with a cart load of bricks.

'Excuse me,' said the third little pig, as politely as his mother had taught him. 'Please can you sell me some bricks so I can build a house?'

'Of course,' said the man. 'Where would you like me to unload them?'

The third little pig looked around and saw a nice patch of ground under a tree.

'Over there,' he pointed.

They all set to work and by nighttime the house of straw and the house of sticks were built but the house of bricks was only just beginning to rise above the ground. The first and second little pigs laughed, they thought their brother was really silly having to work so hard when they had finished."""

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentences = sent_tokenize(text)

# %%
sentences
# Out:
# ["Mrs Pig was very tired: 'Oh dear,' she said to her three little pigs, 'I can’t do this work anymore, I’m afraid you must leave home and make your own way in the world.'",
#  'So the three little pigs set off.',
#  'The first little pig met a man carrying a bundle of straw.',
#  "'Excuse me,' said the first little pig politely.",
#  "'Would you please sell some of your straw so I can make a house?'",
#  'The man readily agreed and the first little pig went off to find a good place to build his house.',
#  'The other little pigs carried on along the road and, soon, they met a man carrying a bundle of sticks.',
#  "'Excuse me,' said the little pig politely.",
#  "'Would you please sell me some sticks so I can build a house?'",
#  'The man readily agreed and the little pig said goodbye to his brother.',
#  "The third little pig didn’t think much of their ideas:\n\n'I’m going to build myself a much bigger, better, stronger house,' he thought, and he carried off down the road until he met a man with a cart load of bricks.",
#  "'Excuse me,' said the third little pig, as politely as his mother had taught him.",
#  "'Please can you sell me some bricks so I can build a house?'",
#  "'Of course,' said the man.",
#  "'Where would you like me to unload them?'",
#  'The third little pig looked around and saw a nice patch of ground under a tree.',
#  "'Over there,' he pointed.",
#  'They all set to work and by nighttime the house of straw and the house of sticks were built but the house of bricks was only just beginning to rise above the ground.',
#  'The first and second little pigs laughed, they thought their brother was really silly having to work so hard when they had finished.']

# %%
tokenized_text = [word_tokenize(sentence) for sentence in sentences]
tokenized_text
# Out:
# [['Mrs',
#   'Pig',
#   'was',
#   'very',
#   'tired',
#   ':',
#   "'Oh",
#   'dear',
#   ',',
#   "'",
#   'she',
#   'said',
#   'to',
#   'her',
#   'three',
#   'little',
#   'pigs',
#   ',',
#   "'",
#   'I',
#   'can',
#   '’',
#   't',
#   'do',
#   'this',
#   'work',
#   'anymore',
#   ',',
#   'I',
#   '’',
#   'm',
#   'afraid',
#   'you',
#   'must',
#   'leave',
#   'home',
#   'and',
#   'make',
#   'your',
#   'own',
#   'way',
#   'in',
#   'the',
#   'world',
#   '.',
#   "'"],
#  ['So', 'the', 'three', 'little', 'pigs', 'set', 'off', '.'],
#  ['The',
#   'first',
#   'little',
#   'pig',
#   'met',
#   'a',
#   'man',
#   'carrying',
#   'a',
#   'bundle',
#   'of',
#   'straw',
#   '.'],
#  ["'Excuse",
#   'me',
#   ',',
#   "'",
#   'said',
#   'the',
#   'first',
#   'little',
#   'pig',
#   'politely',
#   '.'],
#  ["'Would",
#   'you',
#   'please',
#   'sell',
#   'some',
#   'of',
#   'your',
#   'straw',
#   'so',
#   'I',
#   'can',
#   'make',
#   'a',
#   'house',
#   '?',
#   "'"],
#  ['The',
#   'man',
#   'readily',
#   'agreed',
#   'and',
#   'the',
#   'first',
#   'little',
#   'pig',
#   'went',
#   'off',
#   'to',
#   'find',
#   'a',
#   'good',
#   'place',
#   'to',
#   'build',
#   'his',
#   'house',
#   '.'],
#  ['The',
#   'other',
#   'little',
#   'pigs',
#   'carried',
#   'on',
#   'along',
#   'the',
#   'road',
#   'and',
#   ',',
#   'soon',
#   ',',
#   'they',
#   'met',
#   'a',
#   'man',
#   'carrying',
#   'a',
#   'bundle',
#   'of',
#   'sticks',
#   '.'],
#  ["'Excuse", 'me', ',', "'", 'said', 'the', 'little', 'pig', 'politely', '.'],
#  ["'Would",
#   'you',
#   'please',
#   'sell',
#   'me',
#   'some',
#   'sticks',
#   'so',
#   'I',
#   'can',
#   'build',
#   'a',
#   'house',
#   '?',
#   "'"],
#  ['The',
#   'man',
#   'readily',
#   'agreed',
#   'and',
#   'the',
#   'little',
#   'pig',
#   'said',
#   'goodbye',
#   'to',
#   'his',
#   'brother',
#   '.'],
#  ['The',
#   'third',
#   'little',
#   'pig',
#   'didn',
#   '’',
#   't',
#   'think',
#   'much',
#   'of',
#   'their',
#   'ideas',
#   ':',
#   "'",
#   'I',
#   '’',
#   'm',
#   'going',
#   'to',
#   'build',
#   'myself',
#   'a',
#   'much',
#   'bigger',
#   ',',
#   'better',
#   ',',
#   'stronger',
#   'house',
#   ',',
#   "'",
#   'he',
#   'thought',
#   ',',
#   'and',
#   'he',
#   'carried',
#   'off',
#   'down',
#   'the',
#   'road',
#   'until',
#   'he',
#   'met',
#   'a',
#   'man',
#   'with',
#   'a',
#   'cart',
#   'load',
#   'of',
#   'bricks',
#   '.'],
#  ["'Excuse",
#   'me',
#   ',',
#   "'",
#   'said',
#   'the',
#   'third',
#   'little',
#   'pig',
#   ',',
#   'as',
#   'politely',
#   'as',
#   'his',
#   'mother',
#   'had',
#   'taught',
#   'him',
#   '.'],
#  ["'Please",
#   'can',
#   'you',
#   'sell',
#   'me',
#   'some',
#   'bricks',
#   'so',
#   'I',
#   'can',
#   'build',
#   'a',
#   'house',
#   '?',
#   "'"],
#  ["'Of", 'course', ',', "'", 'said', 'the', 'man', '.'],
#  ["'Where", 'would', 'you', 'like', 'me', 'to', 'unload', 'them', '?', "'"],
#  ['The',
#   'third',
#   'little',
#   'pig',
#   'looked',
#   'around',
#   'and',
#   'saw',
#   'a',
#   'nice',
#   'patch',
#   'of',
#   'ground',
#   'under',
#   'a',
#   'tree',
#   '.'],
#  ["'Over", 'there', ',', "'", 'he', 'pointed', '.'],
#  ['They',
#   'all',
#   'set',
#   'to',
#   'work',
#   'and',
#   'by',
#   'nighttime',
#   'the',
#   'house',
#   'of',
#   'straw',
#   'and',
#   'the',
#   'house',
#   'of',
#   'sticks',
#   'were',
#   'built',
#   'but',
#   'the',
#   'house',
#   'of',
#   'bricks',
#   'was',
#   'only',
#   'just',
#   'beginning',
#   'to',
#   'rise',
#   'above',
#   'the',
#   'ground',
#   '.'],
#  ['The',
#   'first',
#   'and',
#   'second',
#   'little',
#   'pigs',
#   'laughed',
#   ',',
#   'they',
#   'thought',
#   'their',
#   'brother',
#   'was',
#   'really',
#   'silly',
#   'having',
#   'to',
#   'work',
#   'so',
#   'hard',
#   'when',
#   'they',
#   'had',
#   'finished',
#   '.']]

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words = set(stopwords.words("english"))

# %%
import string
filtered_text = [[word for word in sent if word.lower() not in stop_words and word not in string.punctuation + '’']for sent in tokenized_text]
filtered_text
# Out:
# [['Mrs',
#   'Pig',
#   'tired',
#   "'Oh",
#   'dear',
#   'said',
#   'three',
#   'little',
#   'pigs',
#   'work',
#   'anymore',
#   'afraid',
#   'must',
#   'leave',
#   'home',
#   'make',
#   'way',
#   'world'],
#  ['three', 'little', 'pigs', 'set'],
#  ['first', 'little', 'pig', 'met', 'man', 'carrying', 'bundle', 'straw'],
#  ["'Excuse", 'said', 'first', 'little', 'pig', 'politely'],
#  ["'Would", 'please', 'sell', 'straw', 'make', 'house'],
#  ['man',
#   'readily',
#   'agreed',
#   'first',
#   'little',
#   'pig',
#   'went',
#   'find',
#   'good',
#   'place',
#   'build',
#   'house'],
#  ['little',
#   'pigs',
#   'carried',
#   'along',
#   'road',
#   'soon',
#   'met',
#   'man',
#   'carrying',
#   'bundle',
#   'sticks'],
#  ["'Excuse", 'said', 'little', 'pig', 'politely'],
#  ["'Would", 'please', 'sell', 'sticks', 'build', 'house'],
#  ['man', 'readily', 'agreed', 'little', 'pig', 'said', 'goodbye', 'brother'],
#  ['third',
#   'little',
#   'pig',
#   'think',
#   'much',
#   'ideas',
#   'going',
#   'build',
#   'much',
#   'bigger',
#   'better',
#   'stronger',
#   'house',
#   'thought',
#   'carried',
#   'road',
#   'met',
#   'man',
#   'cart',
#   'load',
#   'bricks'],
#  ["'Excuse", 'said', 'third', 'little', 'pig', 'politely', 'mother', 'taught'],
#  ["'Please", 'sell', 'bricks', 'build', 'house'],
#  ["'Of", 'course', 'said', 'man'],
#  ["'Where", 'would', 'like', 'unload'],
#  ['third',
#   'little',
#   'pig',
#   'looked',
#   'around',
#   'saw',
#   'nice',
#   'patch',
#   'ground',
#   'tree'],
#  ["'Over", 'pointed'],
#  ['set',
#   'work',
#   'nighttime',
#   'house',
#   'straw',
#   'house',
#   'sticks',
#   'built',
#   'house',
#   'bricks',
#   'beginning',
#   'rise',
#   'ground'],
#  ['first',
#   'second',
#   'little',
#   'pigs',
#   'laughed',
#   'thought',
#   'brother',
#   'really',
#   'silly',
#   'work',
#   'hard',
#   'finished']]

# %%
all_filtered_words = [word for sent in filtered_text for word in sent]
all_filtered_words
# Out:
# ['Mrs',
#  'Pig',
#  'tired',
#  "'Oh",
#  'dear',
#  'said',
#  'three',
#  'little',
#  'pigs',
#  'work',
#  'anymore',
#  'afraid',
#  'must',
#  'leave',
#  'home',
#  'make',
#  'way',
#  'world',
#  'three',
#  'little',
#  'pigs',
#  'set',
#  'first',
#  'little',
#  'pig',
#  'met',
#  'man',
#  'carrying',
#  'bundle',
#  'straw',
#  "'Excuse",
#  'said',
#  'first',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'please',
#  'sell',
#  'straw',
#  'make',
#  'house',
#  'man',
#  'readily',
#  'agreed',
#  'first',
#  'little',
#  'pig',
#  'went',
#  'find',
#  'good',
#  'place',
#  'build',
#  'house',
#  'little',
#  'pigs',
#  'carried',
#  'along',
#  'road',
#  'soon',
#  'met',
#  'man',
#  'carrying',
#  'bundle',
#  'sticks',
#  "'Excuse",
#  'said',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'please',
#  'sell',
#  'sticks',
#  'build',
#  'house',
#  'man',
#  'readily',
#  'agreed',
#  'little',
#  'pig',
#  'said',
#  'goodbye',
#  'brother',
#  'third',
#  'little',
#  'pig',
#  'think',
#  'much',
#  'ideas',
#  'going',
#  'build',
#  'much',
#  'bigger',
#  'better',
#  'stronger',
#  'house',
#  'thought',
#  'carried',
#  'road',
#  'met',
#  'man',
#  'cart',
#  'load',
#  'bricks',
#  "'Excuse",
#  'said',
#  'third',
#  'little',
#  'pig',
#  'politely',
#  'mother',
#  'taught',
#  "'Please",
#  'sell',
#  'bricks',
#  'build',
#  'house',
#  "'Of",
#  'course',
#  'said',
#  'man',
#  "'Where",
#  'would',
#  'like',
#  'unload',
#  'third',
#  'little',
#  'pig',
#  'looked',
#  'around',
#  'saw',
#  'nice',
#  'patch',
#  'ground',
#  'tree',
#  "'Over",
#  'pointed',
#  'set',
#  'work',
#  'nighttime',
#  'house',
#  'straw',
#  'house',
#  'sticks',
#  'built',
#  'house',
#  'bricks',
#  'beginning',
#  'rise',
#  'ground',
#  'first',
#  'second',
#  'little',
#  'pigs',
#  'laughed',
#  'thought',
#  'brother',
#  'really',
#  'silly',
#  'work',
#  'hard',
#  'finished']

# %% [markdown]
# # Завдання 2
#
#  * Зробіть стемінг слів
#  * Зробіть лематизацію слів
#  * Створіть `pandas.DataFrame` зі словами, що мають різний результат при стемінгу та лематизації. Має бути 3 стовпчика:
#   * оригінальне сово
#   * результат стемінгу
#   * результат лематизації

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stemmed_words = [stemmer.stem(word.lower()) for word in all_filtered_words]
stemmed_words
# Out:
# ['mr',
#  'pig',
#  'tire',
#  "'oh",
#  'dear',
#  'said',
#  'three',
#  'littl',
#  'pig',
#  'work',
#  'anymor',
#  'afraid',
#  'must',
#  'leav',
#  'home',
#  'make',
#  'way',
#  'world',
#  'three',
#  'littl',
#  'pig',
#  'set',
#  'first',
#  'littl',
#  'pig',
#  'met',
#  'man',
#  'carri',
#  'bundl',
#  'straw',
#  "'excus",
#  'said',
#  'first',
#  'littl',
#  'pig',
#  'polit',
#  "'would",
#  'pleas',
#  'sell',
#  'straw',
#  'make',
#  'hous',
#  'man',
#  'readili',
#  'agre',
#  'first',
#  'littl',
#  'pig',
#  'went',
#  'find',
#  'good',
#  'place',
#  'build',
#  'hous',
#  'littl',
#  'pig',
#  'carri',
#  'along',
#  'road',
#  'soon',
#  'met',
#  'man',
#  'carri',
#  'bundl',
#  'stick',
#  "'excus",
#  'said',
#  'littl',
#  'pig',
#  'polit',
#  "'would",
#  'pleas',
#  'sell',
#  'stick',
#  'build',
#  'hous',
#  'man',
#  'readili',
#  'agre',
#  'littl',
#  'pig',
#  'said',
#  'goodby',
#  'brother',
#  'third',
#  'littl',
#  'pig',
#  'think',
#  'much',
#  'idea',
#  'go',
#  'build',
#  'much',
#  'bigger',
#  'better',
#  'stronger',
#  'hous',
#  'thought',
#  'carri',
#  'road',
#  'met',
#  'man',
#  'cart',
#  'load',
#  'brick',
#  "'excus",
#  'said',
#  'third',
#  'littl',
#  'pig',
#  'polit',
#  'mother',
#  'taught',
#  "'pleas",
#  'sell',
#  'brick',
#  'build',
#  'hous',
#  "'of",
#  'cours',
#  'said',
#  'man',
#  "'where",
#  'would',
#  'like',
#  'unload',
#  'third',
#  'littl',
#  'pig',
#  'look',
#  'around',
#  'saw',
#  'nice',
#  'patch',
#  'ground',
#  'tree',
#  "'over",
#  'point',
#  'set',
#  'work',
#  'nighttim',
#  'hous',
#  'straw',
#  'hous',
#  'stick',
#  'built',
#  'hous',
#  'brick',
#  'begin',
#  'rise',
#  'ground',
#  'first',
#  'second',
#  'littl',
#  'pig',
#  'laugh',
#  'thought',
#  'brother',
#  'realli',
#  'silli',
#  'work',
#  'hard',
#  'finish']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
lemmatized_words = [lemmatizer.lemmatize(word.lower()) for word in all_filtered_words]

# %%
print(len(all_filtered_words), len(stemmed_words), len(lemmatized_words))
# Out:
# 163 163 163

# %%
import pandas as pd
comp_words_df = pd.DataFrame(data=zip(all_filtered_words, stemmed_words, lemmatized_words), columns=['original', 'stemmed', 'lemmatized'])

# %%
comp_words_df = comp_words_df[comp_words_df['stemmed'] != comp_words_df['lemmatized']]
comp_words_df
# Out:
#       original   stemmed lemmatized
# 2        tired      tire      tired
# 7       little     littl     little
# 10     anymore    anymor    anymore
# 13       leave      leav      leave
# 19      little     littl     little
# 23      little     littl     little
# 27    carrying     carri   carrying
# 28      bundle     bundl     bundle
# 30     'Excuse    'excus    'excuse
# 33      little     littl     little
# 35    politely     polit   politely
# 37      please     pleas     please
# 41       house      hous      house
# 43     readily   readili    readily
# 44      agreed      agre     agreed
# 46      little     littl     little
# 53       house      hous      house
# 54      little     littl     little
# 56     carried     carri    carried
# 62    carrying     carri   carrying
# 63      bundle     bundl     bundle
# 65     'Excuse    'excus    'excuse
# 67      little     littl     little
# 69    politely     polit   politely
# 71      please     pleas     please
# 75       house      hous      house
# 77     readily   readili    readily
# 78      agreed      agre     agreed
# 79      little     littl     little
# 82     goodbye    goodby    goodbye
# 85      little     littl     little
# 90       going        go      going
# 96       house      hous      house
# 98     carried     carri    carried
# 105    'Excuse    'excus    'excuse
# 108     little     littl     little
# 110   politely     polit   politely
# 113    'Please    'pleas    'please
# 117      house      hous      house
# 119     course     cours     course
# 127     little     littl     little
# 129     looked      look     looked
# 137    pointed     point    pointed
# 140  nighttime  nighttim  nighttime
# 141      house      hous      house
# 143      house      hous      house
# 146      house      hous      house
# 148  beginning     begin  beginning
# 153     little     littl     little
# 155    laughed     laugh    laughed
# 158     really    realli     really
# 159      silly     silli      silly
# 162   finished    finish   finished

# %% [markdown]
# # Завдання 3
# Виділіть фрази за такими шаблонами:
#   * прикметник + іменник
#   * (хоча б 1 прикметник) + іменник
#   * (прислівник + дієслово) АБО (дієслово + прислівник)

# %%
all_words = word_tokenize(text)

# %%
all_words = [word for word in all_words if word not in string.punctuation]

# %%
all_words
# Out:
# ['Mrs',
#  'Pig',
#  'was',
#  'very',
#  'tired',
#  "'Oh",
#  'dear',
#  'she',
#  'said',
#  'to',
#  'her',
#  'three',
#  'little',
#  'pigs',
#  'I',
#  'can',
#  '’',
#  't',
#  'do',
#  'this',
#  'work',
#  'anymore',
#  'I',
#  '’',
#  'm',
#  'afraid',
#  'you',
#  'must',
#  'leave',
#  'home',
#  'and',
#  'make',
#  'your',
#  'own',
#  'way',
#  'in',
#  'the',
#  'world',
#  'So',
#  'the',
#  'three',
#  'little',
#  'pigs',
#  'set',
#  'off',
#  'The',
#  'first',
#  'little',
#  'pig',
#  'met',
#  'a',
#  'man',
#  'carrying',
#  'a',
#  'bundle',
#  'of',
#  'straw',
#  "'Excuse",
#  'me',
#  'said',
#  'the',
#  'first',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'you',
#  'please',
#  'sell',
#  'some',
#  'of',
#  'your',
#  'straw',
#  'so',
#  'I',
#  'can',
#  'make',
#  'a',
#  'house',
#  'The',
#  'man',
#  'readily',
#  'agreed',
#  'and',
#  'the',
#  'first',
#  'little',
#  'pig',
#  'went',
#  'off',
#  'to',
#  'find',
#  'a',
#  'good',
#  'place',
#  'to',
#  'build',
#  'his',
#  'house',
#  'The',
#  'other',
#  'little',
#  'pigs',
#  'carried',
#  'on',
#  'along',
#  'the',
#  'road',
#  'and',
#  'soon',
#  'they',
#  'met',
#  'a',
#  'man',
#  'carrying',
#  'a',
#  'bundle',
#  'of',
#  'sticks',
#  "'Excuse",
#  'me',
#  'said',
#  'the',
#  'little',
#  'pig',
#  'politely',
#  "'Would",
#  'you',
#  'please',
#  'sell',
#  'me',
#  'some',
#  'sticks',
#  'so',
#  'I',
#  'can',
#  'build',
#  'a',
#  'house',
#  'The',
#  'man',
#  'readily',
#  'agreed',
#  'and',
#  'the',
#  'little',
#  'pig',
#  'said',
#  'goodbye',
#  'to',
#  'his',
#  'brother',
#  'The',
#  'third',
#  'little',
#  'pig',
#  'didn',
#  '’',
#  't',
#  'think',
#  'much',
#  'of',
#  'their',
#  'ideas',
#  'I',
#  '’',
#  'm',
#  'going',
#  'to',
#  'build',
#  'myself',
#  'a',
#  'much',
#  'bigger',
#  'better',
#  'stronger',
#  'house',
#  'he',
#  'thought',
#  'and',
#  'he',
#  'carried',
#  'off',
#  'down',
#  'the',
#  'road',
#  'until',
#  'he',
#  'met',
#  'a',
#  'man',
#  'with',
#  'a',
#  'cart',
#  'load',
#  'of',
#  'bricks',
#  "'Excuse",
#  'me',
#  'said',
#  'the',
#  'third',
#  'little',
#  'pig',
#  'as',
#  'politely',
#  'as',
#  'his',
#  'mother',
#  'had',
#  'taught',
#  'him',
#  "'Please",
#  'can',
#  'you',
#  'sell',
#  'me',
#  'some',
#  'bricks',
#  'so',
#  'I',
#  'can',
#  'build',
#  'a',
#  'house',
#  "'Of",
#  'course',
#  'said',
#  'the',
#  'man',
#  "'Where",
#  'would',
#  'you',
#  'like',
#  'me',
#  'to',
#  'unload',
#  'them',
#  'The',
#  'third',
#  'little',
#  'pig',
#  'looked',
#  'around',
#  'and',
#  'saw',
#  'a',
#  'nice',
#  'patch',
#  'of',
#  'ground',
#  'under',
#  'a',
#  'tree',
#  "'Over",
#  'there',
#  'he',
#  'pointed',
#  'They',
#  'all',
#  'set',
#  'to',
#  'work',
#  'and',
#  'by',
#  'nighttime',
#  'the',
#  'house',
#  'of',
#  'straw',
#  'and',
#  'the',
#  'house',
#  'of',
#  'sticks',
#  'were',
#  'built',
#  'but',
#  'the',
#  'house',
#  'of',
#  'bricks',
#  'was',
#  'only',
#  'just',
#  'beginning',
#  'to',
#  'rise',
#  'above',
#  'the',
#  'ground',
#  'The',
#  'first',
#  'and',
#  'second',
#  'little',
#  'pigs',
#  'laughed',
#  'they',
#  'thought',
#  'their',
#  'brother',
#  'was',
#  'really',
#  'silly',
#  'having',
#  'to',
#  'work',
#  'so',
#  'hard',
#  'when',
#  'they',
#  'had',
#  'finished']

# %%
# !pip install -q svgling
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.4 MB/s eta 0:00:00

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
tags = nltk.pos_tag(all_words)
tags
# Out:
# [('Mrs', 'NNP'),
#  ('Pig', 'NNP'),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('tired', 'JJ'),
#  ("'Oh", 'CD'),
#  ('dear', 'IN'),
#  ('she', 'PRP'),
#  ('said', 'VBD'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('three', 'CD'),
#  ('little', 'JJ'),
#  ('pigs', 'NNS'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('’', 'VB'),
#  ('t', 'RB'),
#  ('do', 'VB'),
#  ('this', 'DT'),
#  ('work', 'NN'),
#  ('anymore', 'RB'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'JJ'),
#  ('afraid', 'IN'),
#  ('you', 'PRP'),
#  ('must', 'MD'),
#  ('leave', 'VB'),
#  ('home', 'NN'),
#  ('and', 'CC'),
#  ('make', 'VB'),
#  ('your', 'PRP$'),
#  ('own', 'JJ'),
#  ('way', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('So', 'IN'),
#  ('the', 'DT'),
#  ('three', 'CD'),
#  ('little', 'JJ'),
#  ('pigs', 'NNS'),
#  ('set', 'VBD'),
#  ('off', 'RP'),
#  ('The', 'DT'),
#  ('first', 'JJ'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('met', 'VBD'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('carrying', 'VBG'),
#  ('a', 'DT'),
#  ('bundle', 'NN'),
#  ('of', 'IN'),
#  ('straw', 'NN'),
#  ("'Excuse", 'IN'),
#  ('me', 'PRP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('politely', 'RB'),
#  ("'Would", 'MD'),
#  ('you', 'PRP'),
#  ('please', 'VB'),
#  ('sell', 'VB'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('your', 'PRP$'),
#  ('straw', 'NNS'),
#  ('so', 'IN'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('make', 'VB'),
#  ('a', 'DT'),
#  ('house', 'NN'),
#  ('The', 'DT'),
#  ('man', 'NN'),
#  ('readily', 'RB'),
#  ('agreed', 'VBD'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('went', 'VBD'),
#  ('off', 'IN'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('a', 'DT'),
#  ('good', 'JJ'),
#  ('place', 'NN'),
#  ('to', 'TO'),
#  ('build', 'VB'),
#  ('his', 'PRP$'),
#  ('house', 'NN'),
#  ('The', 'DT'),
#  ('other', 'JJ'),
#  ('little', 'JJ'),
#  ('pigs', 'NNS'),
#  ('carried', 'VBD'),
#  ('on', 'IN'),
#  ('along', 'IN'),
#  ('the', 'DT'),
#  ('road', 'NN'),
#  ('and', 'CC'),
#  ('soon', 'RB'),
#  ('they', 'PRP'),
#  ('met', 'VBD'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('carrying', 'VBG'),
#  ('a', 'DT'),
#  ('bundle', 'NN'),
#  ('of', 'IN'),
#  ('sticks', 'NNS'),
#  ("'Excuse", 'IN'),
#  ('me', 'PRP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('politely', 'RB'),
#  ("'Would", 'MD'),
#  ('you', 'PRP'),
#  ('please', 'VB'),
#  ('sell', 'VB'),
#  ('me', 'PRP'),
#  ('some', 'DT'),
#  ('sticks', 'NNS'),
#  ('so', 'IN'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('build', 'VB'),
#  ('a', 'DT'),
#  ('house', 'NN'),
#  ('The', 'DT'),
#  ('man', 'NN'),
#  ('readily', 'RB'),
#  ('agreed', 'VBD'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('said', 'VBD'),
#  ('goodbye', 'NN'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('brother', 'NN'),
#  ('The', 'DT'),
#  ('third', 'JJ'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('didn', 'NN'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('think', 'VBP'),
#  ('much', 'RB'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('ideas', 'NNS'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('build', 'VB'),
#  ('myself', 'PRP'),
#  ('a', 'DT'),
#  ('much', 'RB'),
#  ('bigger', 'JJR'),
#  ('better', 'RB'),
#  ('stronger', 'JJR'),
#  ('house', 'NN'),
#  ('he', 'PRP'),
#  ('thought', 'VBD'),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('carried', 'VBD'),
#  ('off', 'RP'),
#  ('down', 'IN'),
#  ('the', 'DT'),
#  ('road', 'NN'),
#  ('until', 'IN'),
#  ('he', 'PRP'),
#  ('met', 'VBD'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('cart', 'JJ'),
#  ('load', 'NN'),
#  ('of', 'IN'),
#  ('bricks', 'NNS'),
#  ("'Excuse", 'IN'),
#  ('me', 'PRP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('third', 'JJ'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('as', 'RB'),
#  ('politely', 'RB'),
#  ('as', 'IN'),
#  ('his', 'PRP$'),
#  ('mother', 'NN'),
#  ('had', 'VBD'),
#  ('taught', 'VBN'),
#  ('him', 'PRP'),
#  ("'Please", 'VB'),
#  ('can', 'MD'),
#  ('you', 'PRP'),
#  ('sell', 'VB'),
#  ('me', 'PRP'),
#  ('some', 'DT'),
#  ('bricks', 'NNS'),
#  ('so', 'IN'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('build', 'VB'),
#  ('a', 'DT'),
#  ('house', 'NN'),
#  ("'Of", 'POS'),
#  ('course', 'NN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('man', 'NN'),
#  ("'Where", 'POS'),
#  ('would', 'MD'),
#  ('you', 'PRP'),
#  ('like', 'VB'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('unload', 'VB'),
#  ('them', 'PRP'),
#  ('The', 'DT'),
#  ('third', 'JJ'),
#  ('little', 'JJ'),
#  ('pig', 'NN'),
#  ('looked', 'VBD'),
#  ('around', 'IN'),
#  ('and', 'CC'),
#  ('saw', 'VBD'),
#  ('a', 'DT'),
#  ('nice', 'JJ'),
#  ('patch', 'NN'),
#  ('of', 'IN'),
#  ('ground', 'NN'),
#  ('under', 'IN'),
#  ('a', 'DT'),
#  ('tree', 'JJ'),
#  ("'Over", 'NN'),
#  ('there', 'RB'),
#  ('he', 'PRP'),
#  ('pointed', 'VBD'),
#  ('They', 'PRP'),
#  ('all', 'DT'),
#  ('set', 'VBP'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('and', 'CC'),
#  ('by', 'IN'),
#  ('nighttime', 'RB'),
#  ('the', 'DT'),
#  ('house', 'NN'),
#  ('of', 'IN'),
#  ('straw', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('house', 'NN'),
#  ('of', 'IN'),
#  ('sticks', 'NNS'),
#  ('were', 'VBD'),
#  ('built', 'VBN'),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('house', 'NN'),
#  ('of', 'IN'),
#  ('bricks', 'NNS'),
#  ('was', 'VBD'),
#  ('only', 'RB'),
#  ('just', 'RB'),
#  ('beginning', 'VBG'),
#  ('to', 'TO'),
#  ('rise', 'VB'),
#  ('above', 'IN'),
#  ('the', 'DT'),
#  ('ground', 'NN'),
#  ('The', 'DT'),
#  ('first', 'JJ'),
#  ('and', 'CC'),
#  ('second', 'JJ'),
#  ('little', 'JJ'),
#  ('pigs', 'NNS'),
#  ('laughed', 'VBD'),
#  ('they', 'PRP'),
#  ('thought', 'VBD'),
#  ('their', 'PRP$'),
#  ('brother', 'NN'),
#  ('was', 'VBD'),
#  ('really', 'RB'),
#  ('silly', 'RB'),
#  ('having', 'VBG'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('so', 'RB'),
#  ('hard', 'JJ'),
#  ('when', 'WRB'),
#  ('they', 'PRP'),
#  ('had', 'VBD'),
#  ('finished', 'VBN')]

# %%
grammar1 = r"""
    AN: {<JJ.*>+<NN.*>}
    AN: {<JJ.*><NN.*>}
"""

grammar2 = r"""
    RBVB: {<RB.*><VB.*> | <VB.*><RB.*>}
"""
combined_grammar = grammar1 + grammar2

# %%
chunk_parser = nltk.RegexpParser(combined_grammar)

tree = chunk_parser.parse(tags)

# %%
tree
# Out:
# Tree('S', [('Mrs', 'NNP'), ('Pig', 'NNP'), Tree('RBVB', [('was', 'VBD'), ('very', 'RB')]), ('tired', 'JJ'), ("'Oh", 'CD'), ('dear', 'IN'), ('she', 'PRP'), ('said', 'VBD'), ('to', 'TO'), ('her', 'PRP$'), ('three', 'CD'), Tree('AN', [('little', 'JJ'), ('pigs', 'NNS')]), ('I', 'PRP'), ('can', 'MD'), Tree('RBVB', [('’', 'VB'), ('t', 'RB')]), ('do', 'VB'), ('this', 'DT'), ('work', 'NN'), ('anymore', 'RB'), ('I', 'PRP'), ('’', 'VBP'), ('m', 'JJ'), ('afraid', 'IN'), ('you', 'PRP'), ('must', 'MD'), ('leave', 'VB'), ('home', 'NN'), ('and', 'CC'), ('make', 'VB'), ('your', 'PRP$'), Tree('AN', [('own', 'JJ'), ('way', 'NN')]), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('So', 'IN'), ('the', 'DT'), ('three', 'CD'), Tree('AN', [('little', 'JJ'), ('pigs', 'NNS')]), ('set', 'VBD'), ('off', 'RP'), ('The', 'DT'), Tree('AN', [('first', 'JJ'), ('little', 'JJ'), ('pig', 'NN')]), ('met', 'VBD'), ('a', 'DT'), ('man', 'NN'), ('carrying', 'VBG'), ('a', 'DT'), ('bundle', 'NN'), ('of', 'IN'), ('straw', 'NN'), ("'Excuse", 'IN'), ('me', 'PRP'), ('said', 'VBD'), ('the', 'DT'), Tree('AN', [('first', 'JJ'), ('little', 'JJ'), ('pig', 'NN')]), ('politely', 'RB'), ("'Would", 'MD'), ('you', 'PRP'), ('please', 'VB'), ('sell', 'VB'), ('some', 'DT'), ('of', 'IN'), ('your', 'PRP$'), ('straw', 'NNS'), ('so', 'IN'), ('I', 'PRP'), ('can', 'MD'), ('make', 'VB'), ('a', 'DT'), ('house', 'NN'), ('The', 'DT'), ('man', 'NN'), Tree('RBVB', [('readily', 'RB'), ('agreed', 'VBD')]), ('and', 'CC'), ('the', 'DT'), Tree('AN', [('first', 'JJ'), ('little', 'JJ'), ('pig', 'NN')]), ('went', 'VBD'), ('off', 'IN'), ('to', 'TO'), ('find', 'VB'), ('a', 'DT'), Tree('AN', [('good', 'JJ'), ('place', 'NN')]), ('to', 'TO'), ('build', 'VB'), ('his', 'PRP$'), ('house', 'NN'), ('The', 'DT'), Tree('AN', [('other', 'JJ'), ('little', 'JJ'), ('pigs', 'NNS')]), ('carried', 'VBD'), ('on', 'IN'), ('along', 'IN'), ('the', 'DT'), ('road', 'NN'), ('and', 'CC'), ('soon', 'RB'), ('they', 'PRP'), ('met', 'VBD'), ('a', 'DT'), ('man', 'NN'), ('carrying', 'VBG'), ('a', 'DT'), ('bundle', 'NN'), ('of', 'IN'), ('sticks', 'NNS'), ("'Excuse", 'IN'), ('me', 'PRP'), ('said', 'VBD'), ('the', 'DT'), Tree('AN', [('little', 'JJ'), ('pig', 'NN')]), ('politely', 'RB'), ("'Would", 'MD'), ('you', 'PRP'), ('please', 'VB'), ('sell', 'VB'), ('me', 'PRP'), ('some', 'DT'), ('sticks', 'NNS'), ('so', 'IN'), ('I', 'PRP'), ('can', 'MD'), ('build', 'VB'), ('a', 'DT'), ('house', 'NN'), ('The', 'DT'), ('man', 'NN'), Tree('RBVB', [('readily', 'RB'), ('agreed', 'VBD')]), ('and', 'CC'), ('the', 'DT'), Tree('AN', [('little', 'JJ'), ('pig', 'NN')]), ('said', 'VBD'), ('goodbye', 'NN'), ('to', 'TO'), ('his', 'PRP$'), ('brother', 'NN'), ('The', 'DT'), Tree('AN', [('third', 'JJ'), ('little', 'JJ'), ('pig', 'NN')]), ('didn', 'NN'), ('’', 'NNP'), ('t', 'NN'), Tree('RBVB', [('think', 'VBP'), ('much', 'RB')]), ('of', 'IN'), ('their', 'PRP$'), ('ideas', 'NNS'), ('I', 'PRP'), Tree('RBVB', [('’', 'VBP'), ('m', 'RB')]), ('going', 'VBG'), ('to', 'TO'), ('build', 'VB'), ('myself', 'PRP'), ('a', 'DT'), ('much', 'RB'), ('bigger', 'JJR'), ('better', 'RB'), Tree('AN', [('stronger', 'JJR'), ('house', 'NN')]), ('he', 'PRP'), ('thought', 'VBD'), ('and', 'CC'), ('he', 'PRP'), ('carried', 'VBD'), ('off', 'RP'), ('down', 'IN'), ('the', 'DT'), ('road', 'NN'), ('until', 'IN'), ('he', 'PRP'), ('met', 'VBD'), ('a', 'DT'), ('man', 'NN'), ('with', 'IN'), ('a', 'DT'), Tree('AN', [('cart', 'JJ'), ('load', 'NN')]), ('of', 'IN'), ('bricks', 'NNS'), ("'Excuse", 'IN'), ('me', 'PRP'), ('said', 'VBD'), ('the', 'DT'), Tree('AN', [('third', 'JJ'), ('little', 'JJ'), ('pig', 'NN')]), ('as', 'RB'), ('politely', 'RB'), ('as', 'IN'), ('his', 'PRP$'), ('mother', 'NN'), ('had', 'VBD'), ('taught', 'VBN'), ('him', 'PRP'), ("'Please", 'VB'), ('can', 'MD'), ('you', 'PRP'), ('sell', 'VB'), ('me', 'PRP'), ('some', 'DT'), ('bricks', 'NNS'), ('so', 'IN'), ('I', 'PRP'), ('can', 'MD'), ('build', 'VB'), ('a', 'DT'), ('house', 'NN'), ("'Of", 'POS'), ('course', 'NN'), ('said', 'VBD'), ('the', 'DT'), ( ...
